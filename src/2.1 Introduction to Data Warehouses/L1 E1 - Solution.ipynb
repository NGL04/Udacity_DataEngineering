# %% [markdown]
# # Demo 01 -  Sakila Star Schema & ETL
#
# All the database tables in this demo are based on public database samples and transformations
# - `Sakila` is a sample database created by `MySql` [Link](https://dev.mysql.com/doc/sakila/en/sakila-structure.html)
# - The postgresql version of it is called `Pagila` [Link](https://video.udacity-data.com/topher/2021/August/61120e06_pagila-3nf/pagila-3nf.png)
# - The facts and dimension tables design is based on O'Reilly's public dimensional modelling tutorial schema [Link](https://video.udacity-data.com/topher/2021/August/61120d38_pagila-star/pagila-star.png)

# %% [markdown]
# # STEP0: Using ipython-sql
#
# - load ipython-sql: `%load_ext sql`
#
# - To execute SQL queries you write one of the following atop of your cell:
#     - `%sql`
#         - For a one-liner SQL query
#         - You can access a python var using `$`
#     - `%%sql`
#         - For a multi-line SQL query
#         - You can **NOT** access a python var using `$`
#
#
# - Running a connection string like:
# `postgresql://postgres:postgres@db:5432/pagila` connects to the database

# %% [markdown]
# # STEP1 : Connect to the local database where Pagila is loaded

# %% [markdown]
# ##  1.1 Create the pagila db and fill it with data
# - Adding `"!"` at the beginning of a jupyter cell runs a command in a shell, i.e. we are not running python code but we are running the `createdb` and `psql` postgresql commmand-line utilities

# %%
# !PGPASSWORD=student createdb -h 127.0.0.1 -U student pagila_TTestT
# ---> this one works in Git Bash Terminal :-)

# Run in Terminal and enter password manually, as PGPASSWORD=student doesn't work in command here... must be set as environment variable
# Habe C:\Programme\PostgreSQL\14\bin\ zu PATH hinzugefügt, geht jetzt auch ohne
# !C:\Programme\PostgreSQL\14\bin\createdb -h 127.0.0.1 -U student pagila
# !C:\Programme\PostgreSQL\14\bin\psql -q -h 127.0.0.1 -U student -d pagila -f Data/pagila-schema.sql
# !C:\Programme\PostgreSQL\14\bin\psql -q -h 127.0.0.1 -U student -d pagila -f Data/pagila-data.sql
# Out:
# ^C

# %% [markdown]
# ## 1.2 Connect to the newly created db

# %%
# %load_ext sql

# %%
DB_ENDPOINT = "127.0.0.1"
DB = 'pagila'
DB_USER = 'student'
DB_PASSWORD = 'student'
DB_PORT = '5432'

# postgresql://username:password@host:port/database
conn_string = "postgresql://{}:{}@{}:{}/{}" \
                        .format(DB_USER, DB_PASSWORD, DB_ENDPOINT, DB_PORT, DB)

print(conn_string)
# Out:
# postgresql://student:student@127.0.0.1:5432/pagila

# %%
# %sql $conn_string

# %% [markdown]
# # STEP 1.1: Create and populate the star schema

# %% [markdown]
# # STEP2 : Explore the  3NF Schema

# %% [markdown]
# <img src="./pagila-3nf.png" width="50%"/>

# %% [markdown]
# ## 2.1 How much? What data sizes are we looking at?

# %%
nStores = %sql select count(*) from store;
nFilms = %sql select count(*) from film;
nCustomers = %sql select count(*) from customer;
nRentals = %sql select count(*) from rental;
nPayment = %sql select count(*) from payment;
nStaff = %sql select count(*) from staff;
nCity = %sql select count(*) from city;
nCountry = %sql select count(*) from country;

print("nFilms\t\t=", nFilms[0][0])
print("nCustomers\t=", nCustomers[0][0])
print("nRentals\t=", nRentals[0][0])
print("nPayment\t=", nPayment[0][0])
print("nStaff\t\t=", nStaff[0][0])
print("nStores\t\t=", nStores[0][0])
print("nCities\t\t=", nCity[0][0])
print("nCountry\t\t=", nCountry[0][0])
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
# nFilms		= 1000
# nCustomers	= 599
# nRentals	= 16044
# nPayment	= 16049
# nStaff		= 2
# nStores		= 2
# nCities		= 600
# nCountry		= 109

# %% [markdown]
# ## 2.2 When? What time period are we talking about?

# %%
# %%sql
# select min(payment_date) as start, max(payment_date) as end from payment;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
# [(datetime.datetime(2017, 1, 24, 21, 21, 56, 996577, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), datetime.datetime(2017, 5, 14, 13, 44, 29, 996577, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))))]

# %% [markdown]
# ## 2.3 Where? Where do events in this database occur?

# %%
# %%sql
# select district,  sum(city_id) as n
# from address
# group by district
# order by n desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('Shandong', 3237),
#  ('England', 2974),
#  ('So Paulo', 2952),
#  ('West Bengali', 2623),
#  ('Buenos Aires', 2572),
#  ('Uttar Pradesh', 2462),
#  ('California', 2444),
#  ('Southern Tagalog', 1931),
#  ('Tamil Nadu', 1807),
#  ('Hubei', 1790)]

# %% [markdown]
# # STEP3: Perform some simple data analysis

# %% [markdown]
# ## 3.1 Insight 1:   Top Grossing Movies
# - Payments amounts are in table `payment`
# - Movies are in table `film`
# - They are not directly linked, `payment` refers to a `rental`, `rental` refers to an `inventory` item and `inventory` item refers to a `film`
# - `payment` &rarr; `rental` &rarr; `inventory` &rarr; `film`

# %% [markdown]
# ### 3.1.1 Films

# %%
# %%sql
# select film_id, title, release_year, rental_rate, rating  from film limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(1, 'ACADEMY DINOSAUR', 2006, Decimal('0.99'), 'PG'),
#  (2, 'ACE GOLDFINGER', 2006, Decimal('4.99'), 'G'),
#  (3, 'ADAPTATION HOLES', 2006, Decimal('2.99'), 'NC-17'),
#  (4, 'AFFAIR PREJUDICE', 2006, Decimal('2.99'), 'G'),
#  (5, 'AFRICAN EGG', 2006, Decimal('2.99'), 'G')]

# %% [markdown]
# ### 3.1.2 Payments

# %%
# %%sql
# select * from payment limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(16050, 269, 2, 7, Decimal('1.99'), datetime.datetime(2017, 1, 24, 21, 40, 19, 996577, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))),
#  (16051, 269, 1, 98, Decimal('0.99'), datetime.datetime(2017, 1, 25, 15, 16, 50, 996577, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))),
#  (16052, 269, 2, 678, Decimal('6.99'), datetime.datetime(2017, 1, 28, 21, 44, 14, 996577, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))),
#  (16053, 269, 2, 703, Decimal('0.99'), datetime.datetime(2017, 1, 29, 0, 58, 2, 996577, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))),
#  (16054, 269, 1, 750, Decimal('4.99'), datetime.datetime(2017, 1, 29, 8, 10, 6, 996577, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))))]

# %% [markdown]
# ### 3.1.3 Inventory

# %%
# %%sql
# select * from inventory limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(1, 1, 1, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))),
#  (2, 1, 1, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))),
#  (3, 1, 1, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))),
#  (4, 1, 1, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))),
#  (5, 1, 2, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))))]

# %% [markdown]
# ### 3.1.4 Get the movie of every payment

# %%
# %%sql
# SELECT f.title, p.amount, p.payment_date, p.customer_id
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [('SWARM GOLD', Decimal('1.99'), datetime.datetime(2017, 1, 24, 21, 40, 19, 996577, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 269),
#  ('PACKER MADIGAN', Decimal('0.99'), datetime.datetime(2017, 1, 25, 15, 16, 50, 996577, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 269),
#  ('SOMETHING DUCK', Decimal('6.99'), datetime.datetime(2017, 1, 28, 21, 44, 14, 996577, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 269),
#  ('DRACULA CRYSTAL', Decimal('0.99'), datetime.datetime(2017, 1, 29, 0, 58, 2, 996577, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 269),
#  ('CLOSER BANG', Decimal('4.99'), datetime.datetime(2017, 1, 29, 8, 10, 6, 996577, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 269)]

# %% [markdown]
# ### 3.1.5 sum movie rental revenue

# %%
# %%sql
# SELECT f.title, sum(p.amount) as revenue
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# GROUP BY title
# ORDER BY revenue desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('TELEGRAPH VOYAGE', Decimal('231.73')),
#  ('WIFE TURN', Decimal('223.69')),
#  ('ZORRO ARK', Decimal('214.69')),
#  ('GOODFELLAS SALUTE', Decimal('209.69')),
#  ('SATURDAY LAMBS', Decimal('204.72')),
#  ('TITANS JERK', Decimal('201.71')),
#  ('TORQUE BOUND', Decimal('198.72')),
#  ('HARRY IDAHO', Decimal('195.70')),
#  ('INNOCENT USUAL', Decimal('191.74')),
#  ('HUSTLER PARTY', Decimal('190.78'))]

# %% [markdown]
# ## 3.2 Insight 2:   Top grossing cities
# - Payments amounts are in table `payment`
# - Cities are in table `cities`
# - `payment` &rarr; `customer` &rarr; `address` &rarr; `city`

# %% [markdown]
# ### 3.2.1 Get the city of each payment

# %%
# %%sql
# SELECT p.customer_id, p.rental_id, p.amount, ci.city
# FROM payment p
# JOIN customer c  ON ( p.customer_id = c.customer_id )
# JOIN address a ON ( c.address_id = a.address_id )
# JOIN city ci ON ( a.city_id = ci.city_id )
# order by p.payment_date
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [(130, 1, Decimal('2.99'), 'guas Lindas de Gois'),
#  (459, 2, Decimal('2.99'), 'Qomsheh'),
#  (408, 3, Decimal('3.99'), 'Jaffna'),
#  (333, 4, Decimal('4.99'), 'Baku'),
#  (222, 5, Decimal('6.99'), 'Jaroslavl'),
#  (549, 6, Decimal('0.99'), 'Santiago de Compostela'),
#  (269, 7, Decimal('1.99'), 'Salinas'),
#  (239, 8, Decimal('4.99'), 'Ciomas'),
#  (126, 9, Decimal('4.99'), 'Po'),
#  (399, 10, Decimal('5.99'), 'Okara')]

# %% [markdown]
# ### 3.2.2 Top grossing cities

# %%
# %%sql
# SELECT ci.city ,  sum(p.amount) as revenue
# FROM payment p
# JOIN customer c  ON ( p.customer_id = c.customer_id )
# JOIN address a ON ( c.address_id = a.address_id )
# JOIN city ci ON ( a.city_id = ci.city_id )
# group by ci.city
# order by revenue desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('Cape Coral', Decimal('221.55')),
#  ('Saint-Denis', Decimal('216.54')),
#  ('Aurora', Decimal('198.50')),
#  ('Molodetno', Decimal('195.58')),
#  ('Santa Brbara dOeste', Decimal('194.61')),
#  ('Apeldoorn', Decimal('194.61')),
#  ('Qomsheh', Decimal('186.62')),
#  ('London', Decimal('180.52')),
#  ('Ourense (Orense)', Decimal('177.60')),
#  ('Bijapur', Decimal('175.61'))]

# %% [markdown]
# ## 3.3 Insight 3 : Revenue of a movie by customer city and by month

# %% [markdown]
# ### 3.3.1 Total revenue by month

# %%
# %%sql
# SELECT sum(p.amount) as revenue, EXTRACT(month FROM p.payment_date) as month
# from payment p
# group by month
# order by revenue desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(Decimal('28559.46'), Decimal('4')),
#  (Decimal('23886.56'), Decimal('3')),
#  (Decimal('9631.88'), Decimal('2')),
#  (Decimal('4824.43'), Decimal('1')),
#  (Decimal('514.18'), Decimal('5'))]

# %% [markdown]
# ### 3.3.2 Each movie by customer city and by month (data cube)

# %%
# %%sql
# SELECT f.title, p.amount, p.customer_id, ci.city, p.payment_date,EXTRACT(month FROM p.payment_date) as month
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# JOIN customer c  ON ( p.customer_id = c.customer_id )
# JOIN address a ON ( c.address_id = a.address_id )
# JOIN city ci ON ( a.city_id = ci.city_id )
# order by p.payment_date
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('BLANKET BEVERLY', Decimal('2.99'), 130, 'guas Lindas de Gois', datetime.datetime(2017, 1, 24, 21, 21, 56, 996577, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), Decimal('1')),
#  ('FREAKY POCUS', Decimal('2.99'), 459, 'Qomsheh', datetime.datetime(2017, 1, 24, 21, 22, 59, 996577, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), Decimal('1')),
#  ('GRADUATE LORD', Decimal('3.99'), 408, 'Jaffna', datetime.datetime(2017, 1, 24, 21, 32, 5, 996577, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), Decimal('1')),
#  ('LOVE SUICIDES', Decimal('4.99'), 333, 'Baku', datetime.datetime(2017, 1, 24, 21, 33, 7, 996577, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), Decimal('1')),
#  ('IDOLS SNATCHERS', Decimal('6.99'), 222, 'Jaroslavl', datetime.datetime(2017, 1, 24, 21, 33, 47, 996577, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), Decimal('1')),
#  ('MYSTIC TRUMAN', Decimal('0.99'), 549, 'Santiago de Compostela', datetime.datetime(2017, 1, 24, 21, 36, 33, 996577, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), Decimal('1')),
#  ('SWARM GOLD', Decimal('1.99'), 269, 'Salinas', datetime.datetime(2017, 1, 24, 21, 40, 19, 996577, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), Decimal('1')),
#  ('LAWLESS VISION', Decimal('4.99'), 239, 'Ciomas', datetime.datetime(2017, 1, 24, 22, 0, 12, 996577, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), Decimal('1')),
#  ('MATRIX SNOWMAN', Decimal('4.99'), 126, 'Po', datetime.datetime(2017, 1, 24, 22, 29, 6, 996577, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), Decimal('1')),
#  ('HANGING DEEP', Decimal('5.99'), 399, 'Okara', datetime.datetime(2017, 1, 24, 22, 30, 47, 996577, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), Decimal('1'))]

# %% [markdown]
# ### 3.3.3 Sum of revenue of each movie by customer city and by month

# %%
# %%sql
# SELECT f.title, ci.city,EXTRACT(month FROM p.payment_date) as month, sum(p.amount) as revenue
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# JOIN customer c  ON ( p.customer_id = c.customer_id )
# JOIN address a ON ( c.address_id = a.address_id )
# JOIN city ci ON ( a.city_id = ci.city_id )
# group by (f.title, ci.city, month)
# order by month, revenue desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('SHOW LORD', 'Mannheim', Decimal('1'), Decimal('11.99')),
#  ('KISSING DOLLS', 'Toulon', Decimal('1'), Decimal('10.99')),
#  ('TELEGRAPH VOYAGE', 'Naala-Porto', Decimal('1'), Decimal('10.99')),
#  ('AMERICAN CIRCUS', 'Callao', Decimal('1'), Decimal('10.99')),
#  ('CASUALTIES ENCINO', 'Warren', Decimal('1'), Decimal('10.99')),
#  ('AUTUMN CROW', 'Ashgabat', Decimal('1'), Decimal('9.99')),
#  ('MIDSUMMER GROUNDHOG', 'Vaduz', Decimal('1'), Decimal('9.99')),
#  ('DAY UNFAITHFUL', 'Baybay', Decimal('1'), Decimal('9.99')),
#  ('CALIFORNIA BIRDS', 'Plock', Decimal('1'), Decimal('9.99')),
#  ('DARKO DORADO', 'Bhilwara', Decimal('1'), Decimal('9.99'))]

# %% [markdown]
# # STEP 4 : Creating Facts & Dimensions

# %% [markdown]
# <img src="pagila-star.png" width="50%"/>

# %%
# %%sql
# CREATE TABLE dimDate
# (
#   date_key integer NOT NULL PRIMARY KEY,
#   date date NOT NULL,
#   year smallint NOT NULL,
#   quarter smallint NOT NULL,
#   month smallint NOT NULL,
#   day smallint NOT NULL,
#   week smallint NOT NULL,
#   is_weekend boolean
# );
#
# CREATE TABLE dimCustomer
# (
#   customer_key SERIAL PRIMARY KEY,
#   customer_id  smallint NOT NULL,
#   first_name   varchar(45) NOT NULL,
#   last_name    varchar(45) NOT NULL,
#   email        varchar(50),
#   address      varchar(50) NOT NULL,
#   address2     varchar(50),
#   district     varchar(20) NOT NULL,
#   city         varchar(50) NOT NULL,
#   country      varchar(50) NOT NULL,
#   postal_code  varchar(10),
#   phone        varchar(20) NOT NULL,
#   active       smallint NOT NULL,
#   create_date  timestamp NOT NULL,
#   start_date   date NOT NULL,
#   end_date     date NOT NULL
# );
#
# CREATE TABLE dimMovie
# (
#   movie_key          SERIAL PRIMARY KEY,
#   film_id            smallint NOT NULL,
#   title              varchar(255) NOT NULL,
#   description        text,
#   release_year       year,
#   language           varchar(20) NOT NULL,
#   original_language  varchar(20),
#   rental_duration    smallint NOT NULL,
#   length             smallint NOT NULL,
#   rating             varchar(5) NOT NULL,
#   special_features   varchar(60) NOT NULL
# );
# CREATE TABLE dimStore
# (
#   store_key           SERIAL PRIMARY KEY,
#   store_id            smallint NOT NULL,
#   address             varchar(50) NOT NULL,
#   address2            varchar(50),
#   district            varchar(20) NOT NULL,
#   city                varchar(50) NOT NULL,
#   country             varchar(50) NOT NULL,
#   postal_code         varchar(10),
#   manager_first_name  varchar(45) NOT NULL,
#   manager_last_name   varchar(45) NOT NULL,
#   start_date          date NOT NULL,
#   end_date            date NOT NULL
# );
# CREATE TABLE factSales
# (
#   sales_key        SERIAL PRIMARY KEY,
#   date_key         INT NOT NULL REFERENCES dimDate(date_key),
#   customer_key     INT NOT NULL REFERENCES dimCustomer(customer_key),
#   movie_key        INT NOT NULL REFERENCES dimMovie(movie_key),
#   store_key        INT NOT NULL REFERENCES dimStore(store_key),
#   sales_amount     decimal(5,2) NOT NULL
# );
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# (psycopg2.errors.DuplicateTable) FEHLER:  Relation »dimdate« existiert bereits
#
# [SQL: CREATE TABLE dimDate
# (
#   date_key integer NOT NULL PRIMARY KEY,
#   date date NOT NULL,
#   year smallint NOT NULL,
#   quarter smallint NOT NULL,
#   month smallint NOT NULL,
#   day smallint NOT NULL,
#   week smallint NOT NULL,
#   is_weekend boolean
# );]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
# %%sql
# SELECT column_name, data_type
# FROM information_schema.columns
# WHERE table_name   = 'factsales'
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 6 rows affected.
# [('sales_key', 'integer'),
#  ('date_key', 'integer'),
#  ('customer_key', 'integer'),
#  ('movie_key', 'integer'),
#  ('store_key', 'integer'),
#  ('sales_amount', 'numeric')]

# %% [markdown]
# # STEP 5: ETL the data from 3NF tables to Facts & Dimension Tables

# %%
# %%sql
# INSERT INTO dimDate (date_key, date, year, quarter, month, day, week, is_weekend)
# SELECT DISTINCT(TO_CHAR(payment_date :: DATE, 'yyyyMMDD')::integer) AS date_key,
#        date(payment_date)                                           AS date,
#        EXTRACT(year FROM payment_date)                              AS year,
#        EXTRACT(quarter FROM payment_date)                           AS quarter,
#        EXTRACT(month FROM payment_date)                             AS month,
#        EXTRACT(day FROM payment_date)                               AS day,
#        EXTRACT(week FROM payment_date)                              AS week,
#        CASE WHEN EXTRACT(ISODOW FROM payment_date) IN (6, 7) THEN true ELSE false END AS is_weekend
# FROM payment;
#
#
# INSERT INTO dimCustomer (customer_key, customer_id, first_name, last_name, email, address, address2, district, city, country, postal_code, phone, active, create_date, start_date, end_date)
# SELECT c.customer_id AS customer_key,
#        c.customer_id,
#        c.first_name,
#        c.last_name,
#        c.email,
#        a.address,
#        a.address2,
#        a.district,
#        ci.city,
#        co.country,
#        a.postal_code,
#        a.phone,
#        c.active,
#        c.create_date,
#        now()         AS start_date,
#        now()         AS end_date
# FROM customer c
# JOIN address a  ON (c.address_id = a.address_id)
# JOIN city ci    ON (a.city_id = ci.city_id)
# JOIN country co ON (ci.country_id = co.country_id);
#
# INSERT INTO dimMovie (movie_key, film_id, title, description, release_year, language, original_language, rental_duration, length, rating, special_features)
# SELECT f.film_id      AS movie_key,
#        f.film_id,
#        f.title,
#        f.description,
#        f.release_year,
#        l.name         AS language,
#        orig_lang.name AS original_language,
#        f.rental_duration,
#        f.length,
#        f.rating,
#        f.special_features
# FROM film f
# JOIN language l              ON (f.language_id=l.language_id)
# LEFT JOIN language orig_lang ON (f.original_language_id = orig_lang.language_id);
#
# INSERT INTO dimStore (store_key, store_id, address, address2, district, city, country, postal_code, manager_first_name, manager_last_name, start_date, end_date)
# SELECT s.store_id    AS store_key,
#        s.store_id,
#        a.address,
#        a.address2,
#        a.district,
#        c.city,
#        co.country,
#        a.postal_code,
#        st.first_name AS manager_first_name,
#        st.last_name  AS manager_last_name,
#        now()         AS start_date,
#        now()         AS end_date
# FROM store s
# JOIN staff st   ON (s.manager_staff_id = st.staff_id)
# JOIN address a  ON (s.address_id = a.address_id)
# JOIN city c     ON (a.city_id = c.city_id)
# JOIN country co ON (c.country_id = co.country_id);
#
# INSERT INTO factSales (date_key, customer_key, movie_key, store_key, sales_amount)
# SELECT TO_CHAR(p.payment_date :: DATE, 'yyyyMMDD')::integer AS date_key ,
#        p.customer_id                                        AS customer_key,
#        i.film_id                                            AS movie_key,
#        i.store_id                                           AS store_key,
#        p.amount                                             AS sales_amount
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id );
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 40 rows affected.
# 599 rows affected.
# 1000 rows affected.
# 2 rows affected.
# 16049 rows affected.
# []

# %% [markdown]
# # STEP 6: Repeat the computation from the facts & dimension table

# %% [markdown]
# ## 6.1 Facts Table has all the needed dimensions, no need for deep joins

# %%
# %%time
# %%sql
SELECT movie_key, date_key, customer_key, sales_amount
FROM factSales 
limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# CPU times: total: 0 ns
# Wall time: 4.97 ms
# [(870, 20170124, 269, Decimal('1.99')),
#  (651, 20170125, 269, Decimal('0.99')),
#  (818, 20170128, 269, Decimal('6.99')),
#  (249, 20170129, 269, Decimal('0.99')),
#  (159, 20170129, 269, Decimal('4.99'))]

# %% [markdown]
# ## 6.2 Join fact table with dimensions to replace keys with attributes

# %%
# %%time
# %%sql
SELECT dimMovie.title, dimDate.month, dimCustomer.city, sales_amount
FROM factSales 
JOIN dimMovie on (dimMovie.movie_key = factSales.movie_key)
JOIN dimDate on (dimDate.date_key = factSales.date_key)
JOIN dimCustomer on (dimCustomer.customer_key = factSales.customer_key)
limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# CPU times: total: 0 ns
# Wall time: 0 ns
# [('SWARM GOLD', 1, 'Salinas', Decimal('1.99')),
#  ('PACKER MADIGAN', 1, 'Salinas', Decimal('0.99')),
#  ('SOMETHING DUCK', 1, 'Salinas', Decimal('6.99')),
#  ('DRACULA CRYSTAL', 1, 'Salinas', Decimal('0.99')),
#  ('CLOSER BANG', 1, 'Salinas', Decimal('4.99'))]

# %%
# %%time
# %%sql
SELECT dimMovie.title, dimDate.month, dimCustomer.city, sum(sales_amount) as revenue
FROM factSales 
JOIN dimMovie    on (dimMovie.movie_key      = factSales.movie_key)
JOIN dimDate     on (dimDate.date_key         = factSales.date_key)
JOIN dimCustomer on (dimCustomer.customer_key = factSales.customer_key)
group by (dimMovie.title, dimDate.month, dimCustomer.city)
order by dimMovie.title, dimDate.month, dimCustomer.city, revenue desc;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 15992 rows affected.
# CPU times: total: 46.9 ms
# Wall time: 188 ms
# [('ACADEMY DINOSAUR', 1, 'Celaya', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 1, 'Cianjur', Decimal('1.99')),
#  ('ACADEMY DINOSAUR', 2, 'San Lorenzo', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 2, 'Sullana', Decimal('1.99')),
#  ('ACADEMY DINOSAUR', 2, 'Udaipur', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 3, 'Almirante Brown', Decimal('1.99')),
#  ('ACADEMY DINOSAUR', 3, 'Goinia', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 3, 'Kaliningrad', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 3, 'Kurashiki', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 3, 'Livorno', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 3, 'Nukualofa', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 3, 'Rajkot', Decimal('3.99')),
#  ('ACADEMY DINOSAUR', 3, 'Sivas', Decimal('3.99')),
#  ('ACADEMY DINOSAUR', 3, 'Tabriz', Decimal('3.99')),
#  ('ACADEMY DINOSAUR', 4, 'Charlotte Amalie', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 4, 'Hamilton', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 4, 'Jos Azueta', Decimal('1.99')),
#  ('ACADEMY DINOSAUR', 4, 'Lipetsk', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 4, 'London', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 4, 'Pjatigorsk', Decimal('1.99')),
#  ('ACADEMY DINOSAUR', 4, 'Sucre', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 4, 'Tel Aviv-Jaffa', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 4, 'Vila Velha', Decimal('0.99')),
#  ('ACE GOLDFINGER', 3, 'Binzhou', Decimal('8.99')),
#  ('ACE GOLDFINGER', 3, 'Kumbakonam', Decimal('4.99')),
#  ('ACE GOLDFINGER', 3, 'Pereira', Decimal('8.99')),
#  ('ACE GOLDFINGER', 3, 'Touliu', Decimal('9.99')),
#  ('ACE GOLDFINGER', 4, 'Simferopol', Decimal('9.99')),
#  ('ACE GOLDFINGER', 4, 'Soshanguve', Decimal('4.99')),
#  ('ACE GOLDFINGER', 5, 'Balikesir', Decimal('4.99')),
#  ('ADAPTATION HOLES', 1, 'Shikarpur', Decimal('2.99')),
#  ('ADAPTATION HOLES', 2, 'Jelets', Decimal('2.99')),
#  ('ADAPTATION HOLES', 3, 'al-Qatif', Decimal('2.99')),
#  ('ADAPTATION HOLES', 3, 'Cayenne', Decimal('2.99')),
#  ('ADAPTATION HOLES', 3, 'Coacalco de Berriozbal', Decimal('2.99')),
#  ('ADAPTATION HOLES', 3, 'Salinas', Decimal('2.99')),
#  ('ADAPTATION HOLES', 3, 'Santa Brbara dOeste', Decimal('2.99')),
#  ('ADAPTATION HOLES', 3, 'Sasebo', Decimal('4.99')),
#  ('ADAPTATION HOLES', 4, 'Jodhpur', Decimal('2.99')),
#  ('ADAPTATION HOLES', 4, 'Miraj', Decimal('2.99')),
#  ('ADAPTATION HOLES', 4, 'Ogbomosho', Decimal('2.99')),
#  ('ADAPTATION HOLES', 4, 'Urawa', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 1, 'Hidalgo', Decimal('3.99')),
#  ('AFFAIR PREJUDICE', 1, 'Tuguegarao', Decimal('3.99')),
#  ('AFFAIR PREJUDICE', 2, 'Changzhou', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 2, 'Crdoba', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 3, 'Aparecida de Goinia', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 3, 'Atinsk', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 3, 'Avellaneda', Decimal('6.99')),
#  ('AFFAIR PREJUDICE', 3, 'Caracas', Decimal('6.99')),
#  ('AFFAIR PREJUDICE', 3, 'Laiwu', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 3, 'Rancagua', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 4, 'Chiayi', Decimal('4.99')),
#  ('AFFAIR PREJUDICE', 4, 'Ciomas', Decimal('5.99')),
#  ('AFFAIR PREJUDICE', 4, 'Lublin', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 4, 'Malm', Decimal('5.99')),
#  ('AFFAIR PREJUDICE', 4, 'Palghat (Palakkad)', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 4, 'Qomsheh', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 4, 's-Hertogenbosch', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 4, 'Saint-Denis', Decimal('3.99')),
#  ('AFFAIR PREJUDICE', 4, 'San Felipe de Puerto Plata', Decimal('4.99')),
#  ('AFFAIR PREJUDICE', 4, 'Sirjan', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 4, 'Sokoto', Decimal('4.99')),
#  ('AFFAIR PREJUDICE', 4, 'Tiefa', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 5, 'Caracas', Decimal('2.99')),
#  ('AFRICAN EGG', 1, 'Ivanovo', Decimal('3.99')),
#  ('AFRICAN EGG', 2, 'Okayama', Decimal('3.99')),
#  ('AFRICAN EGG', 2, 'Richmond Hill', Decimal('4.99')),
#  ('AFRICAN EGG', 3, 'Rampur', Decimal('3.99')),
#  ('AFRICAN EGG', 3, 'Smolensk', Decimal('4.99')),
#  ('AFRICAN EGG', 3, 'Tokat', Decimal('2.99')),
#  ('AFRICAN EGG', 4, 'Jedda', Decimal('4.99')),
#  ('AFRICAN EGG', 4, 'Jhansi', Decimal('2.99')),
#  ('AFRICAN EGG', 4, 'Kitwe', Decimal('4.99')),
#  ('AFRICAN EGG', 4, 'Salzburg', Decimal('5.99')),
#  ('AFRICAN EGG', 4, 'York', Decimal('4.99')),
#  ('AFRICAN EGG', 5, 'al-Manama', Decimal('2.99')),
#  ('AGENT TRUMAN', 1, 'Coatzacoalcos', Decimal('8.99')),
#  ('AGENT TRUMAN', 1, 'Izumisano', Decimal('5.99')),
#  ('AGENT TRUMAN', 2, 'Antofagasta', Decimal('3.99')),
#  ('AGENT TRUMAN', 2, 'Moscow', Decimal('8.99')),
#  ('AGENT TRUMAN', 2, 'Taizz', Decimal('6.99')),
#  ('AGENT TRUMAN', 3, 'Bhilwara', Decimal('8.99')),
#  ('AGENT TRUMAN', 3, 'Chisinau', Decimal('4.99')),
#  ('AGENT TRUMAN', 3, 'Citrus Heights', Decimal('6.99')),
#  ('AGENT TRUMAN', 3, 'Emeishan', Decimal('3.99')),
#  ('AGENT TRUMAN', 3, 'Luzinia', Decimal('3.99')),
#  ('AGENT TRUMAN', 3, 'Mogiljov', Decimal('6.99')),
#  ('AGENT TRUMAN', 3, 'Omdurman', Decimal('7.99')),
#  ('AGENT TRUMAN', 3, 'Sunnyvale', Decimal('4.99')),
#  ('AGENT TRUMAN', 3, 'Usak', Decimal('7.99')),
#  ('AGENT TRUMAN', 4, 'Aurora', Decimal('4.99')),
#  ('AGENT TRUMAN', 4, 'Huixquilucan', Decimal('4.99')),
#  ('AGENT TRUMAN', 4, 'Matsue', Decimal('5.99')),
#  ('AGENT TRUMAN', 4, 'Nantou', Decimal('2.99')),
#  ('AGENT TRUMAN', 4, 'Pontianak', Decimal('7.99')),
#  ('AGENT TRUMAN', 4, 'Quilmes', Decimal('2.99')),
#  ('AGENT TRUMAN', 4, 'Tafuna', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 2, 'Cavite', Decimal('7.99')),
#  ('AIRPLANE SIERRA', 2, 'Lubumbashi', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 3, 'Ibirit', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 3, 'Iwakuni', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 3, 'Johannesburg', Decimal('7.99')),
#  ('AIRPLANE SIERRA', 3, 'Jurez', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 3, 'Mahajanga', Decimal('5.99')),
#  ('AIRPLANE SIERRA', 3, 's-Hertogenbosch', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 4, 'Bhusawal', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 4, 'Kuwana', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 4, 'Salamanca', Decimal('5.99')),
#  ('AIRPLANE SIERRA', 4, 'Sincelejo', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 4, 'Tsuyama', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 4, 'Yuncheng', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 4, 'Zalantun', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 1, 'Okinawa', Decimal('5.99')),
#  ('AIRPORT POLLOCK', 1, 'Pemalang', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 1, 'Taguig', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 2, 'Molodetno', Decimal('5.99')),
#  ('AIRPORT POLLOCK', 2, 'Portoviejo', Decimal('6.99')),
#  ('AIRPORT POLLOCK', 2, 'Vaduz', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 3, 'Augusta-Richmond County', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 3, 'Lilongwe', Decimal('7.99')),
#  ('AIRPORT POLLOCK', 3, 'Lublin', Decimal('6.99')),
#  ('AIRPORT POLLOCK', 3, 'Peoria', Decimal('5.99')),
#  ('AIRPORT POLLOCK', 3, 'Yangor', Decimal('5.99')),
#  ('AIRPORT POLLOCK', 4, 'Bamenda', Decimal('5.99')),
#  ('AIRPORT POLLOCK', 4, 'Dhaka', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 4, 'Erlangen', Decimal('5.99')),
#  ('AIRPORT POLLOCK', 4, 'Fukuyama', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 4, 'Palghat (Palakkad)', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 4, 'San Juan Bautista Tuxtepec', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 4, 'Sanaa', Decimal('4.99')),
#  ('ALABAMA DEVIL', 3, 'Greensboro', Decimal('5.99')),
#  ('ALABAMA DEVIL', 3, 'Halifax', Decimal('7.99')),
#  ('ALABAMA DEVIL', 3, 'Otsu', Decimal('8.99')),
#  ('ALABAMA DEVIL', 3, 'Sunnyvale', Decimal('2.99')),
#  ('ALABAMA DEVIL', 3, 'Zaoyang', Decimal('5.99')),
#  ('ALABAMA DEVIL', 4, 'Arlington', Decimal('8.99')),
#  ('ALABAMA DEVIL', 4, 'Asuncin', Decimal('5.99')),
#  ('ALABAMA DEVIL', 4, 'Changhwa', Decimal('4.99')),
#  ('ALABAMA DEVIL', 4, 'Eskisehir', Decimal('2.99')),
#  ('ALABAMA DEVIL', 4, 'Kanazawa', Decimal('4.99')),
#  ('ALABAMA DEVIL', 4, 'Mit Ghamr', Decimal('2.99')),
#  ('ALABAMA DEVIL', 4, 'Probolinggo', Decimal('8.99')),
#  ('ALADDIN CALENDAR', 2, 'Kaduna', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 2, 'Kisumu', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 2, 'La Plata', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 2, 'Olomouc', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 3, 'Adoni', Decimal('6.99')),
#  ('ALADDIN CALENDAR', 3, 'Balaiha', Decimal('6.99')),
#  ('ALADDIN CALENDAR', 3, 'Coacalco de Berriozbal', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 3, 'Deba Habe', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 3, 'Dos Quebradas', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 3, 'Halisahar', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 3, 'Mwanza', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 3, 'Ranchi', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 3, 'Sogamoso', Decimal('7.99')),
#  ('ALADDIN CALENDAR', 3, 'Zalantun', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 4, 'Effon-Alaiye', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 4, 'Esfahan', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 4, 'Gulbarga', Decimal('7.99')),
#  ('ALADDIN CALENDAR', 4, 'Hodeida', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 4, 'Izumisano', Decimal('7.99')),
#  ('ALADDIN CALENDAR', 4, 'Monclova', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 4, 'Okinawa', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 4, 'Stockport', Decimal('5.99')),
#  ('ALADDIN CALENDAR', 4, 'Valencia', Decimal('7.99')),
#  ('ALAMO VIDEOTAPE', 1, 'Arecibo', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 1, 'Yuzhou', Decimal('3.99')),
#  ('ALAMO VIDEOTAPE', 2, 'Meixian', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 2, 'Rio Claro', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 2, 'Tarlac', Decimal('1.99')),
#  ('ALAMO VIDEOTAPE', 3, 'Baicheng', Decimal('1.99')),
#  ('ALAMO VIDEOTAPE', 3, 'Bat Yam', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 3, 'Ife', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 3, 'Jinchang', Decimal('1.99')),
#  ('ALAMO VIDEOTAPE', 3, 'Myingyan', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 3, 'Papeete', Decimal('1.99')),
#  ('ALAMO VIDEOTAPE', 3, 'Pudukkottai', Decimal('3.99')),
#  ('ALAMO VIDEOTAPE', 3, 'Stara Zagora', Decimal('1.99')),
#  ('ALAMO VIDEOTAPE', 3, 'Tanauan', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 4, 'Berhampore (Baharampur)', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 4, 'Duisburg', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 4, 'Emmen', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 4, 'Grand Prairie', Decimal('1.99')),
#  ('ALAMO VIDEOTAPE', 4, 'Idfu', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 4, 'Lapu-Lapu', Decimal('1.98')),
#  ('ALAMO VIDEOTAPE', 4, 'Owo', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 4, 'Pemalang', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 4, 'Zeleznogorsk', Decimal('0.99')),
#  ('ALASKA PHANTOM', 1, 'Nezahualcyotl', Decimal('0.99')),
#  ('ALASKA PHANTOM', 1, 'Zhezqazghan', Decimal('2.99')),
#  ('ALASKA PHANTOM', 2, 'al-Qadarif', Decimal('0.99')),
#  ('ALASKA PHANTOM', 2, 'Braslia', Decimal('2.99')),
#  ('ALASKA PHANTOM', 2, 'Maring', Decimal('0.99')),
#  ('ALASKA PHANTOM', 2, 'Sterling Heights', Decimal('1.99')),
#  ('ALASKA PHANTOM', 2, 'Touliu', Decimal('0.99')),
#  ('ALASKA PHANTOM', 3, 'Dhule (Dhulia)', Decimal('2.99')),
#  ('ALASKA PHANTOM', 3, 'Laohekou', Decimal('1.99')),
#  ('ALASKA PHANTOM', 3, 'Nabereznyje Telny', Decimal('0.99')),
#  ('ALASKA PHANTOM', 3, 'Nantou', Decimal('0.99')),
#  ('ALASKA PHANTOM', 3, 'Peoria', Decimal('3.99')),
#  ('ALASKA PHANTOM', 3, 'Saint Louis', Decimal('0.99')),
#  ('ALASKA PHANTOM', 3, 'Szkesfehrvr', Decimal('1.99')),
#  ('ALASKA PHANTOM', 3, 'Zhezqazghan', Decimal('0.99')),
#  ('ALASKA PHANTOM', 4, 'al-Hawiya', Decimal('0.99')),
#  ('ALASKA PHANTOM', 4, 'Baicheng', Decimal('0.99')),
#  ('ALASKA PHANTOM', 4, 'Bhilwara', Decimal('3.99')),
#  ('ALASKA PHANTOM', 4, 'Dhule (Dhulia)', Decimal('0.99')),
#  ('ALASKA PHANTOM', 4, 'Lhokseumawe', Decimal('1.99')),
#  ('ALASKA PHANTOM', 4, 'Ljubertsy', Decimal('0.99')),
#  ('ALASKA PHANTOM', 4, 'Mandi Bahauddin', Decimal('0.99')),
#  ('ALASKA PHANTOM', 4, 'Niznekamsk', Decimal('2.99')),
#  ('ALASKA PHANTOM', 4, 'Omdurman', Decimal('0.99')),
#  ('ALASKA PHANTOM', 4, 'Tiefa', Decimal('0.99')),
#  ('ALASKA PHANTOM', 4, 'Xiangtan', Decimal('1.99')),
#  ('ALI FOREVER', 3, 'Esfahan', Decimal('5.99')),
#  ('ALI FOREVER', 3, 'Lubumbashi', Decimal('4.99')),
#  ('ALI FOREVER', 3, 'Ourense (Orense)', Decimal('9.99')),
#  ('ALI FOREVER', 3, 'Sharja', Decimal('4.99')),
#  ('ALI FOREVER', 4, 'Cuauhtmoc', Decimal('7.99')),
#  ('ALI FOREVER', 4, 'Jakarta', Decimal('4.99')),
#  ('ALI FOREVER', 4, 'Maikop', Decimal('5.99')),
#  ('ALI FOREVER', 4, 'Vaduz', Decimal('4.99')),
#  ('ALI FOREVER', 5, 'Huixquilucan', Decimal('4.99')),
#  ('ALIEN CENTER', 1, 'Caracas', Decimal('2.99')),
#  ('ALIEN CENTER', 1, 'Escobar', Decimal('2.99')),
#  ('ALIEN CENTER', 2, 'Baiyin', Decimal('2.99')),
#  ('ALIEN CENTER', 2, 'Lengshuijiang', Decimal('2.99')),
#  ('ALIEN CENTER', 2, 'Rancagua', Decimal('4.99')),
#  ('ALIEN CENTER', 3, 'Bag', Decimal('2.99')),
#  ('ALIEN CENTER', 3, 'Hsichuh', Decimal('2.99')),
#  ('ALIEN CENTER', 3, 'Huejutla de Reyes', Decimal('2.99')),
#  ('ALIEN CENTER', 3, 'Kragujevac', Decimal('2.99')),
#  ('ALIEN CENTER', 3, 'Memphis', Decimal('6.99')),
#  ('ALIEN CENTER', 3, 'Nagareyama', Decimal('2.99')),
#  ('ALIEN CENTER', 3, 'San Felipe de Puerto Plata', Decimal('5.99')),
#  ('ALIEN CENTER', 3, 'Sanya', Decimal('4.99')),
#  ('ALIEN CENTER', 3, 'Songkhla', Decimal('2.99')),
#  ('ALIEN CENTER', 4, 'Cuman', Decimal('2.99')),
#  ('ALIEN CENTER', 4, 'El Fuerte', Decimal('4.99')),
#  ('ALIEN CENTER', 4, 'Emeishan', Decimal('6.99')),
#  ('ALIEN CENTER', 4, 'Juazeiro do Norte', Decimal('3.99')),
#  ('ALIEN CENTER', 4, 'Richmond Hill', Decimal('2.99')),
#  ('ALIEN CENTER', 4, 'Shahr-e Kord', Decimal('2.99')),
#  ('ALIEN CENTER', 4, 'Xiangfan', Decimal('6.99')),
#  ('ALIEN CENTER', 4, 'Zhezqazghan', Decimal('5.99')),
#  ('ALLEY EVOLUTION', 1, 'Najafabad', Decimal('5.99')),
#  ('ALLEY EVOLUTION', 2, 'Lancaster', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 2, 'Mexicali', Decimal('6.99')),
#  ('ALLEY EVOLUTION', 3, 'Aden', Decimal('4.99')),
#  ('ALLEY EVOLUTION', 3, 'Jos Azueta', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 3, 'Kalisz', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 3, 'Ponce', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 3, 'Shahr-e Kord', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 3, 'Tuguegarao', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 4, 'Esfahan', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 4, 'NDjamna', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 4, 'Shikarpur', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 4, 'Tonghae', Decimal('4.99')),
#  ('ALLEY EVOLUTION', 4, 'Tsaotun', Decimal('2.99')),
#  ('ALONE TRIP', 1, 'Arak', Decimal('0.99')),
#  ('ALONE TRIP', 2, 'Almirante Brown', Decimal('0.99')),
#  ('ALONE TRIP', 2, 'Tuguegarao', Decimal('3.99')),
#  ('ALONE TRIP', 3, 'Kamjanets-Podilskyi', Decimal('3.99')),
#  ('ALONE TRIP', 3, 'Lungtan', Decimal('2.99')),
#  ('ALONE TRIP', 3, 'NDjamna', Decimal('0.99')),
#  ('ALONE TRIP', 3, 'Sincelejo', Decimal('2.99')),
#  ('ALONE TRIP', 3, 'Sousse', Decimal('4.99')),
#  ('ALONE TRIP', 3, 'Sterling Heights', Decimal('4.99')),
#  ('ALONE TRIP', 3, 'Tarsus', Decimal('2.99')),
#  ('ALONE TRIP', 3, 'Vinh', Decimal('1.99')),
#  ('ALONE TRIP', 4, 'Arecibo', Decimal('1.99')),
#  ('ALONE TRIP', 4, 'Cabuyao', Decimal('1.99')),
#  ('ALONE TRIP', 4, 'Hami', Decimal('6.99')),
#  ('ALONE TRIP', 4, 'Huixquilucan', Decimal('4.99')),
#  ('ALONE TRIP', 4, 'Mwanza', Decimal('6.99')),
#  ('ALONE TRIP', 4, 'Syktyvkar', Decimal('6.99')),
#  ('ALONE TRIP', 5, 'Tanza', Decimal('0.99')),
#  ('ALTER VICTORY', 1, 'Ezhou', Decimal('0.99')),
#  ('ALTER VICTORY', 1, 'Vinh', Decimal('0.99')),
#  ('ALTER VICTORY', 2, 'Charlotte Amalie', Decimal('0.99')),
#  ('ALTER VICTORY', 2, 'Cianjur', Decimal('0.99')),
#  ('ALTER VICTORY', 2, 'Purnea (Purnia)', Decimal('0.99')),
#  ('ALTER VICTORY', 3, 'Alessandria', Decimal('0.99')),
#  ('ALTER VICTORY', 3, 'Bijapur', Decimal('0.99')),
#  ('ALTER VICTORY', 3, 'Kamyin', Decimal('0.99')),
#  ('ALTER VICTORY', 3, 'Korolev', Decimal('0.99')),
#  ('ALTER VICTORY', 3, 'Meixian', Decimal('0.99')),
#  ('ALTER VICTORY', 3, 'Tongliao', Decimal('1.99')),
#  ('ALTER VICTORY', 4, 'Addis Abeba', Decimal('1.99')),
#  ('ALTER VICTORY', 4, 'Avellaneda', Decimal('0.99')),
#  ('ALTER VICTORY', 4, 'Bandar Seri Begawan', Decimal('0.99')),
#  ('ALTER VICTORY', 4, 'Boksburg', Decimal('0.99')),
#  ('ALTER VICTORY', 4, 'Kitwe', Decimal('3.99')),
#  ('ALTER VICTORY', 4, 'Nantou', Decimal('0.99')),
#  ('ALTER VICTORY', 4, 'Shaoguan', Decimal('3.99')),
#  ('ALTER VICTORY', 4, 'Shimonoseki', Decimal('0.99')),
#  ('ALTER VICTORY', 4, 'Sirjan', Decimal('3.99')),
#  ('ALTER VICTORY', 4, 'Tiefa', Decimal('0.99')),
#  ('ALTER VICTORY', 4, 'Urawa', Decimal('0.99')),
#  ('AMADEUS HOLY', 1, 'La Plata', Decimal('0.99')),
#  ('AMADEUS HOLY', 2, 'Denizli', Decimal('0.99')),
#  ('AMADEUS HOLY', 2, 'Jakarta', Decimal('0.99')),
#  ('AMADEUS HOLY', 2, 'Kurashiki', Decimal('0.99')),
#  ('AMADEUS HOLY', 2, 'Myingyan', Decimal('0.99')),
#  ('AMADEUS HOLY', 3, 'Araatuba', Decimal('0.99')),
#  ('AMADEUS HOLY', 3, 'Citt del Vaticano', Decimal('1.99')),
#  ('AMADEUS HOLY', 3, 'Joliet', Decimal('3.99')),
#  ('AMADEUS HOLY', 3, 'Laredo', Decimal('0.99')),
#  ('AMADEUS HOLY', 3, 'Matamoros', Decimal('0.99')),
#  ('AMADEUS HOLY', 3, 'Shubra al-Khayma', Decimal('3.99')),
#  ('AMADEUS HOLY', 3, 'Vila Velha', Decimal('0.99')),
#  ('AMADEUS HOLY', 4, 'Arak', Decimal('0.99')),
#  ('AMADEUS HOLY', 4, 'Bilbays', Decimal('1.99')),
#  ('AMADEUS HOLY', 4, 'Hohhot', Decimal('1.99')),
#  ('AMADEUS HOLY', 4, 'Jining', Decimal('0.99')),
#  ('AMADEUS HOLY', 4, 'Nabereznyje Telny', Decimal('0.99')),
#  ('AMADEUS HOLY', 4, 'Pjatigorsk', Decimal('0.99')),
#  ('AMADEUS HOLY', 4, 'Poos de Caldas', Decimal('3.99')),
#  ('AMADEUS HOLY', 4, 'Warren', Decimal('1.99')),
#  ('AMADEUS HOLY', 5, 'London', Decimal('0.99')),
#  ('AMELIE HELLFIGHTERS', 2, 'Acua', Decimal('4.99')),
#  ('AMELIE HELLFIGHTERS', 2, 'Ipoh', Decimal('5.99')),
#  ('AMELIE HELLFIGHTERS', 3, 'Anpolis', Decimal('4.99')),
#  ('AMELIE HELLFIGHTERS', 3, 'Sterling Heights', Decimal('4.99')),
#  ('AMELIE HELLFIGHTERS', 3, 'Tonghae', Decimal('8.99')),
#  ('AMELIE HELLFIGHTERS', 4, 'Botshabelo', Decimal('5.99')),
#  ('AMELIE HELLFIGHTERS', 4, 'Funafuti', Decimal('9.99')),
#  ('AMELIE HELLFIGHTERS', 4, 'Madiun', Decimal('4.99')),
#  ('AMELIE HELLFIGHTERS', 4, 'Meixian', Decimal('6.99')),
#  ('AMELIE HELLFIGHTERS', 4, 'So Bernardo do Campo', Decimal('9.99')),
#  ('AMERICAN CIRCUS', 1, 'Callao', Decimal('10.99')),
#  ('AMERICAN CIRCUS', 1, 'Juazeiro do Norte', Decimal('4.99')),
#  ('AMERICAN CIRCUS', 2, 'Dos Quebradas', Decimal('9.99')),
#  ('AMERICAN CIRCUS', 2, 'El Fuerte', Decimal('6.99')),
#  ('AMERICAN CIRCUS', 2, 'Oulu', Decimal('4.99')),
#  ('AMERICAN CIRCUS', 3, 'Bayugan', Decimal('4.99')),
#  ('AMERICAN CIRCUS', 3, 'Bergamo', Decimal('5.99')),
#  ('AMERICAN CIRCUS', 3, 'Bijapur', Decimal('10.99')),
#  ('AMERICAN CIRCUS', 3, 'Changhwa', Decimal('4.99')),
#  ('AMERICAN CIRCUS', 3, 'Imus', Decimal('4.99')),
#  ('AMERICAN CIRCUS', 3, 'Konotop', Decimal('10.99')),
#  ('AMERICAN CIRCUS', 3, 'Nagaon', Decimal('4.99')),
#  ('AMERICAN CIRCUS', 3, 'Oulu', Decimal('4.99')),
#  ('AMERICAN CIRCUS', 4, 'Benguela', Decimal('9.99')),
#  ('AMERICAN CIRCUS', 4, 'Bydgoszcz', Decimal('4.99')),
#  ('AMERICAN CIRCUS', 4, 'Cabuyao', Decimal('8.99')),
#  ('AMERICAN CIRCUS', 4, 'Halle/Saale', Decimal('8.99')),
#  ('AMERICAN CIRCUS', 4, 'Juazeiro do Norte', Decimal('9.99')),
#  ('AMERICAN CIRCUS', 4, 'Nador', Decimal('8.99')),
#  ('AMERICAN CIRCUS', 4, 'Saint-Denis', Decimal('10.99')),
#  ('AMERICAN CIRCUS', 4, 'Tiefa', Decimal('8.99')),
#  ('AMERICAN CIRCUS', 5, 'Lipetsk', Decimal('4.99')),
#  ('AMISTAD MIDSUMMER', 2, 'Akron', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 2, 'Mysore', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 2, 'Shimonoseki', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 3, 'Elista', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 3, 'Garland', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 3, 'Jastrzebie-Zdrj', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 3, 'Kolpino', Decimal('3.99')),
#  ('AMISTAD MIDSUMMER', 3, 'Miyakonojo', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 3, 's-Hertogenbosch', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 3, 'Vijayawada', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 3, 'Zanzibar', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 4, 'Apeldoorn', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 4, 'Arecibo', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 4, 'Avellaneda', Decimal('4.99')),
#  ('AMISTAD MIDSUMMER', 4, 'Cavite', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 4, 'Effon-Alaiye', Decimal('5.99')),
#  ('AMISTAD MIDSUMMER', 4, 'Nantou', Decimal('3.99')),
#  ('AMISTAD MIDSUMMER', 4, 'Sasebo', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 4, 'Usak', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 4, 'Xinxiang', Decimal('3.99')),
#  ('AMISTAD MIDSUMMER', 5, 'Imus', Decimal('2.99')),
#  ('ANACONDA CONFESSIONS', 1, 'Fengshan', Decimal('0.99')),
#  ('ANACONDA CONFESSIONS', 1, 'Tarsus', Decimal('1.99')),
#  ('ANACONDA CONFESSIONS', 2, 'Athenai', Decimal('6.99')),
#  ('ANACONDA CONFESSIONS', 2, 'Dallas', Decimal('0.99')),
#  ('ANACONDA CONFESSIONS', 2, 'Kermanshah', Decimal('1.99')),
#  ('ANACONDA CONFESSIONS', 2, 'Nanyang', Decimal('3.99')),
#  ('ANACONDA CONFESSIONS', 2, 'Otsu', Decimal('5.99')),
#  ('ANACONDA CONFESSIONS', 3, 'Botshabelo', Decimal('0.99')),
#  ('ANACONDA CONFESSIONS', 3, 'Haldia', Decimal('0.99')),
#  ('ANACONDA CONFESSIONS', 3, 'Roanoke', Decimal('5.99')),
#  ('ANACONDA CONFESSIONS', 3, 'Shanwei', Decimal('2.99')),
#  ('ANACONDA CONFESSIONS', 3, 'Uttarpara-Kotrung', Decimal('0.99')),
#  ('ANACONDA CONFESSIONS', 4, 'Batman', Decimal('5.99')),
#  ('ANACONDA CONFESSIONS', 4, 'Caracas', Decimal('1.99')),
#  ('ANACONDA CONFESSIONS', 4, 'Charlotte Amalie', Decimal('0.99')),
#  ('ANACONDA CONFESSIONS', 4, 'Jelets', Decimal('1.99')),
#  ('ANACONDA CONFESSIONS', 4, 'Molodetno', Decimal('3.99')),
#  ('ANACONDA CONFESSIONS', 4, 'Sambhal', Decimal('2.99')),
#  ('ANACONDA CONFESSIONS', 4, 'San Juan Bautista Tuxtepec', Decimal('2.99')),
#  ('ANACONDA CONFESSIONS', 4, 'Tanza', Decimal('3.99')),
#  ('ANACONDA CONFESSIONS', 4, 'Vitria de Santo Anto', Decimal('0.99')),
#  ('ANALYZE HOOSIERS', 2, 'Saint Louis', Decimal('4.99')),
#  ('ANALYZE HOOSIERS', 2, 'Xintai', Decimal('2.99')),
#  ('ANALYZE HOOSIERS', 2, 'Yuncheng', Decimal('2.99')),
#  ('ANALYZE HOOSIERS', 3, 'Bijapur', Decimal('3.99')),
#  ('ANALYZE HOOSIERS', 3, 'Ciudad del Este', Decimal('2.99')),
#  ('ANALYZE HOOSIERS', 3, 'Joliet', Decimal('2.99')),
#  ('ANALYZE HOOSIERS', 3, 'Tartu', Decimal('4.99')),
#  ('ANALYZE HOOSIERS', 4, 'Ambattur', Decimal('4.99')),
#  ('ANALYZE HOOSIERS', 4, 'Celaya', Decimal('3.99')),
#  ('ANALYZE HOOSIERS', 4, 'Citrus Heights', Decimal('4.99')),
#  ('ANALYZE HOOSIERS', 4, 'Kurashiki', Decimal('5.99')),
#  ('ANALYZE HOOSIERS', 4, 'Kuwana', Decimal('2.99')),
#  ('ANALYZE HOOSIERS', 4, 'Usak', Decimal('2.99')),
#  ('ANALYZE HOOSIERS', 4, 'Valparai', Decimal('3.99')),
#  ('ANGELS LIFE', 1, 'Adana', Decimal('6.99')),
#  ('ANGELS LIFE', 1, 'Salala', Decimal('8.99')),
#  ('ANGELS LIFE', 2, 'Arecibo', Decimal('3.99')),
#  ('ANGELS LIFE', 2, 'Kermanshah', Decimal('3.99')),
#  ('ANGELS LIFE', 2, 'Urawa', Decimal('2.99')),
#  ('ANGELS LIFE', 3, 'Fukuyama', Decimal('3.99')),
#  ('ANGELS LIFE', 3, 'Greensboro', Decimal('2.99')),
#  ('ANGELS LIFE', 3, 'Kakamigahara', Decimal('2.99')),
#  ('ANGELS LIFE', 3, 'Nagareyama', Decimal('5.99')),
#  ('ANGELS LIFE', 3, 'Salamanca', Decimal('8.99')),
#  ('ANGELS LIFE', 3, 'San Juan Bautista Tuxtepec', Decimal('6.99')),
#  ('ANGELS LIFE', 3, 'Teboksary', Decimal('6.99')),
#  ('ANGELS LIFE', 3, 'Wroclaw', Decimal('7.99')),
#  ('ANGELS LIFE', 4, 'Ambattur', Decimal('2.99')),
#  ('ANGELS LIFE', 4, 'Augusta-Richmond County', Decimal('2.99')),
#  ('ANGELS LIFE', 4, 'Carmen', Decimal('5.99')),
#  ('ANGELS LIFE', 4, 'Kakamigahara', Decimal('3.99')),
#  ('ANGELS LIFE', 4, 'Korolev', Decimal('7.99')),
#  ('ANGELS LIFE', 4, 'Olomouc', Decimal('2.99')),
#  ('ANGELS LIFE', 4, 'Rampur', Decimal('8.99')),
#  ('ANGELS LIFE', 4, 'Sharja', Decimal('6.99')),
#  ('ANGELS LIFE', 4, 'York', Decimal('2.99')),
#  ('ANNIE IDENTITY', 1, 'Jedda', Decimal('3.99')),
#  ('ANNIE IDENTITY', 1, 'Maring', Decimal('3.99')),
#  ('ANNIE IDENTITY', 1, 'Tel Aviv-Jaffa', Decimal('0.99')),
#  ('ANNIE IDENTITY', 2, 'Battambang', Decimal('2.99')),
#  ('ANNIE IDENTITY', 2, 'Ede', Decimal('5.99')),
#  ('ANNIE IDENTITY', 2, 'Goinia', Decimal('0.99')),
#  ('ANNIE IDENTITY', 2, 'Tama', Decimal('0.99')),
#  ('ANNIE IDENTITY', 3, 'Ashqelon', Decimal('4.99')),
#  ('ANNIE IDENTITY', 3, 'Czestochowa', Decimal('4.99')),
#  ('ANNIE IDENTITY', 3, 'Myingyan', Decimal('1.99')),
#  ('ANNIE IDENTITY', 3, 'Pangkal Pinang', Decimal('0.99')),
#  ('ANNIE IDENTITY', 3, 'Santa F', Decimal('2.99')),
#  ('ANNIE IDENTITY', 3, 'Shaoguan', Decimal('6.99')),
#  ('ANNIE IDENTITY', 3, 'Yuncheng', Decimal('0.99')),
#  ('ANNIE IDENTITY', 4, 'Cabuyao', Decimal('0.99')),
#  ('ANNIE IDENTITY', 4, 'Luzinia', Decimal('0.99')),
#  ('ANNIE IDENTITY', 4, 'Oyo', Decimal('0.99')),
#  ('ANNIE IDENTITY', 4, 'Szkesfehrvr', Decimal('0.99')),
#  ('ANNIE IDENTITY', 4, 'Vilnius', Decimal('1.99')),
#  ('ANNIE IDENTITY', 4, 'Zanzibar', Decimal('0.99')),
#  ('ANNIE IDENTITY', 4, 'Zaria', Decimal('5.99')),
#  ('ANNIE IDENTITY', 4, 'Zhoushan', Decimal('2.99')),
#  ('ANONYMOUS HUMAN', 2, 'Uruapan', Decimal('1.99')),
#  ('ANONYMOUS HUMAN', 2, 'Varanasi (Benares)', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 3, 'Basel', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 3, 'Ezhou', Decimal('2.99')),
#  ('ANONYMOUS HUMAN', 3, 'Kowloon and New Kowloon', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 3, 'La Romana', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 3, 'San Bernardino', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 3, 'Zhezqazghan', Decimal('1.99')),
#  ('ANONYMOUS HUMAN', 4, 'Dhaka', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 4, 'Iwakuni', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 4, 'Kamakura', Decimal('1.99')),
#  ('ANONYMOUS HUMAN', 4, 'Liepaja', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 4, 'Richmond Hill', Decimal('0.99')),
#  ('ANTHEM LUKE', 1, 'Lengshuijiang', Decimal('6.99')),
#  ('ANTHEM LUKE', 1, 'Pyongyang', Decimal('4.99')),
#  ('ANTHEM LUKE', 1, 'Uluberia', Decimal('4.99')),
#  ('ANTHEM LUKE', 2, 'Ashgabat', Decimal('4.99')),
#  ('ANTHEM LUKE', 2, 'Cuauhtmoc', Decimal('4.99')),
#  ('ANTHEM LUKE', 2, 'San Felipe del Progreso', Decimal('4.99')),
#  ('ANTHEM LUKE', 3, 'Acua', Decimal('4.99')),
#  ('ANTHEM LUKE', 3, 'Fukuyama', Decimal('4.99')),
#  ('ANTHEM LUKE', 3, 'Ozamis', Decimal('4.99')),
#  ('ANTHEM LUKE', 4, 'Boa Vista', Decimal('8.99')),
#  ('ANTHEM LUKE', 4, 'Changzhou', Decimal('4.99')),
#  ('ANTHEM LUKE', 4, 'Coacalco de Berriozbal', Decimal('4.99')),
#  ('ANTHEM LUKE', 4, 'Kirovo-Tepetsk', Decimal('4.99')),
#  ('ANTHEM LUKE', 4, 'Kuwana', Decimal('5.99')),
#  ('ANTHEM LUKE', 4, 'Lhokseumawe', Decimal('8.99')),
#  ('ANTITRUST TOMATOES', 1, 'Erlangen', Decimal('2.99')),
#  ('ANTITRUST TOMATOES', 1, 'Novoterkassk', Decimal('2.99')),
#  ('ANTITRUST TOMATOES', 2, 'Lapu-Lapu', Decimal('6.99')),
#  ('ANTITRUST TOMATOES', 2, 'Sharja', Decimal('3.99')),
#  ('ANTITRUST TOMATOES', 3, 'Malm', Decimal('2.99')),
#  ('ANTITRUST TOMATOES', 3, 'Pereira', Decimal('2.99')),
#  ('ANTITRUST TOMATOES', 4, 'Bhimavaram', Decimal('3.99')),
#  ('ANTITRUST TOMATOES', 4, 'Fuyu', Decimal('4.99')),
#  ('ANTITRUST TOMATOES', 4, 'Vijayawada', Decimal('2.99')),
#  ('ANTITRUST TOMATOES', 4, 'Ziguinchor', Decimal('2.99')),
#  ('ANYTHING SAVANNAH', 1, 'Halle/Saale', Decimal('2.99')),
#  ('ANYTHING SAVANNAH', 2, 'Araatuba', Decimal('4.99')),
#  ('ANYTHING SAVANNAH', 2, 'Mexicali', Decimal('6.99')),
#  ('ANYTHING SAVANNAH', 3, 'Cam Ranh', Decimal('3.99')),
#  ('ANYTHING SAVANNAH', 3, 'El Monte', Decimal('5.99')),
#  ('ANYTHING SAVANNAH', 3, 'Gandhinagar', Decimal('2.99')),
#  ('ANYTHING SAVANNAH', 3, 'Yangor', Decimal('7.99')),
#  ('ANYTHING SAVANNAH', 4, 'Banjul', Decimal('7.99')),
#  ('ANYTHING SAVANNAH', 4, 'Zaoyang', Decimal('2.99')),
#  ('APACHE DIVINE', 1, 'Cavite', Decimal('4.99')),
#  ('APACHE DIVINE', 1, 'Mukateve', Decimal('7.99')),
#  ('APACHE DIVINE', 1, 'So Leopoldo', Decimal('4.99')),
#  ('APACHE DIVINE', 2, 'Bamenda', Decimal('4.99')),
#  ('APACHE DIVINE', 2, 'Cam Ranh', Decimal('4.99')),
#  ('APACHE DIVINE', 2, 'Iwaki', Decimal('4.99')),
#  ('APACHE DIVINE', 2, 'Taizz', Decimal('4.99')),
#  ('APACHE DIVINE', 3, 'Balikesir', Decimal('6.99')),
#  ('APACHE DIVINE', 3, 'Boksburg', Decimal('7.99')),
#  ('APACHE DIVINE', 3, 'El Fuerte', Decimal('6.99')),
#  ('APACHE DIVINE', 3, 'Guadalajara', Decimal('4.99')),
#  ('APACHE DIVINE', 3, 'Kanazawa', Decimal('4.99')),
#  ('APACHE DIVINE', 3, 'Maikop', Decimal('5.99')),
#  ('APACHE DIVINE', 3, 'Moscow', Decimal('5.99')),
#  ('APACHE DIVINE', 3, 'Okinawa', Decimal('8.99')),
#  ('APACHE DIVINE', 3, 'Sorocaba', Decimal('4.99')),
#  ('APACHE DIVINE', 3, 'Urawa', Decimal('4.99')),
#  ('APACHE DIVINE', 3, 'Zanzibar', Decimal('4.99')),
#  ('APACHE DIVINE', 4, 'Bandar Seri Begawan', Decimal('4.99')),
#  ('APACHE DIVINE', 4, 'Carmen', Decimal('4.99')),
#  ('APACHE DIVINE', 4, 'Greensboro', Decimal('4.99')),
#  ('APACHE DIVINE', 4, 'Jaffna', Decimal('4.99')),
#  ('APACHE DIVINE', 4, 'Kimberley', Decimal('5.99')),
#  ('APACHE DIVINE', 4, 'Malm', Decimal('4.99')),
#  ('APACHE DIVINE', 4, 'Mit Ghamr', Decimal('6.99')),
#  ('APACHE DIVINE', 4, 'Oshawa', Decimal('4.99')),
#  ('APACHE DIVINE', 4, 'Pereira', Decimal('5.99')),
#  ('APACHE DIVINE', 4, 'Robamba', Decimal('4.99')),
#  ('APACHE DIVINE', 4, 'Taguig', Decimal('5.99')),
#  ('APACHE DIVINE', 4, 'Tiefa', Decimal('4.99')),
#  ('APACHE DIVINE', 4, 'York', Decimal('7.99')),
#  ('APOCALYPSE FLAMINGOS', 2, 'Kalisz', Decimal('5.99')),
#  ('APOCALYPSE FLAMINGOS', 3, 'Chandrapur', Decimal('4.99')),
#  ('APOCALYPSE FLAMINGOS', 3, 'Ikerre', Decimal('4.99')),
#  ('APOCALYPSE FLAMINGOS', 4, 'Belm', Decimal('4.99')),
#  ('APOCALYPSE FLAMINGOS', 4, 'Blumenau', Decimal('4.99')),
#  ('APOCALYPSE FLAMINGOS', 4, 'Ruse', Decimal('4.99')),
#  ('ARABIA DOGMA', 1, 'Tartu', Decimal('0.99')),
#  ('ARABIA DOGMA', 2, 'Qalyub', Decimal('0.99')),
#  ('ARABIA DOGMA', 2, 'Toulouse', Decimal('0.99')),
#  ('ARABIA DOGMA', 3, 'Amroha', Decimal('0.99')),
#  ('ARABIA DOGMA', 3, 'La Plata', Decimal('3.99')),
#  ('ARABIA DOGMA', 3, 'London', Decimal('3.99')),
#  ('ARABIA DOGMA', 3, 'Lubumbashi', Decimal('0.99')),
#  ('ARABIA DOGMA', 3, 'Monclova', Decimal('3.99')),
#  ('ARABIA DOGMA', 3, 'Tokat', Decimal('1.99')),
#  ('ARABIA DOGMA', 4, 'Changzhou', Decimal('0.99')),
#  ('ARABIA DOGMA', 4, 'Lapu-Lapu', Decimal('0.99')),
#  ('ARABIA DOGMA', 4, 'Tuguegarao', Decimal('0.99')),
#  ('ARABIA DOGMA', 4, 'Usak', Decimal('0.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 2, 'Arlington', Decimal('4.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 2, 'Bhusawal', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 2, 'Mwene-Ditu', Decimal('5.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 2, 'Tonghae', Decimal('4.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3, 'Czestochowa', Decimal('6.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3, 'Higashiosaka', Decimal('3.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3, 'Kimberley', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3, 'Matsue', Decimal('3.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3, 'Ondo', Decimal('6.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3, 'Parbhani', Decimal('3.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3, 'Zalantun', Decimal('5.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Chapra', Decimal('6.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Dadu', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Fuyu', Decimal('3.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Gaziantep', Decimal('7.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Goinia', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Jamalpur', Decimal('4.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Kamakura', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Myingyan', Decimal('3.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Rio Claro', Decimal('3.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Roanoke', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Usak', Decimal('5.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Vicente Lpez', Decimal('7.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Zhezqazghan', Decimal('2.99')),
#  ('ARIZONA BANG', 2, 'guas Lindas de Gois', Decimal('2.99')),
#  ('ARIZONA BANG', 2, 'Jalib al-Shuyukh', Decimal('5.99')),
#  ('ARIZONA BANG', 2, 'Szkesfehrvr', Decimal('2.99')),
#  ('ARIZONA BANG', 3, 'Hamilton', Decimal('2.99')),
#  ('ARIZONA BANG', 3, 'Kowloon and New Kowloon', Decimal('7.99')),
#  ('ARIZONA BANG', 3, 'Molodetno', Decimal('4.99')),
#  ('ARIZONA BANG', 3, 'Nantou', Decimal('2.99')),
#  ('ARIZONA BANG', 3, 'Palghat (Palakkad)', Decimal('7.99')),
#  ('ARIZONA BANG', 3, 'Pontianak', Decimal('4.99')),
#  ('ARIZONA BANG', 3, 'Probolinggo', Decimal('2.99')),
#  ('ARIZONA BANG', 3, 'Rajkot', Decimal('7.99')),
#  ('ARIZONA BANG', 3, 'Salala', Decimal('2.99')),
#  ('ARIZONA BANG', 3, 'Shikarpur', Decimal('4.99')),
#  ('ARIZONA BANG', 3, 'Springs', Decimal('5.99')),
#  ('ARIZONA BANG', 3, 'Vijayawada', Decimal('6.99')),
#  ('ARIZONA BANG', 4, 'Battambang', Decimal('3.99')),
#  ('ARIZONA BANG', 4, 'Davao', Decimal('4.99')),
#  ('ARIZONA BANG', 4, 'Lancaster', Decimal('5.99')),
#  ('ARIZONA BANG', 4, 'Liepaja', Decimal('7.99')),
#  ('ARIZONA BANG', 4, 'Osmaniye', Decimal('2.99')),
#  ('ARIZONA BANG', 4, 'Saint-Denis', Decimal('2.99')),
#  ('ARMAGEDDON LOST', 1, 'Dallas', Decimal('3.99')),
#  ('ARMAGEDDON LOST', 2, 'Surakarta', Decimal('4.99')),
#  ('ARMAGEDDON LOST', 2, 'Tallahassee', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 3, 'Bhavnagar', Decimal('3.99')),
#  ('ARMAGEDDON LOST', 3, 'Dzerzinsk', Decimal('5.99')),
#  ('ARMAGEDDON LOST', 3, 'Hanoi', Decimal('1.99')),
#  ('ARMAGEDDON LOST', 3, 'Nanyang', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 3, 'NDjamna', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 3, 'Rio Claro', Decimal('1.99')),
#  ('ARMAGEDDON LOST', 4, 'Ambattur', Decimal('2.99')),
#  ('ARMAGEDDON LOST', 4, 'Bradford', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 4, 'Cheju', Decimal('1.99')),
#  ('ARMAGEDDON LOST', 4, 'Cianjur', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 4, 'Hiroshima', Decimal('2.99')),
#  ('ARMAGEDDON LOST', 4, 'Luzinia', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 4, 'Nakhon Sawan', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 4, 'Rae Bareli', Decimal('3.99')),
#  ('ARMAGEDDON LOST', 4, 'Saint-Denis', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 4, 'Szkesfehrvr', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 4, 'Uijongbu', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 5, 'Trshavn', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 1, 'Lublin', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 1, 'Sunnyvale', Decimal('3.99')),
#  ('ARMY FLINTSTONES', 2, 'Kamarhati', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 2, 'Rae Bareli', Decimal('2.99')),
#  ('ARMY FLINTSTONES', 2, 'Sterling Heights', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 3, 'Boa Vista', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 3, 'Lengshuijiang', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 3, 'Po', Decimal('3.99')),
#  ('ARMY FLINTSTONES', 3, 'Yamuna Nagar', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 3, 'Yuzhou', Decimal('4.99')),
#  ('ARMY FLINTSTONES', 4, 'Aden', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 4, 'Cavite', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 4, 'Jodhpur', Decimal('2.99')),
#  ('ARMY FLINTSTONES', 4, 'Kurashiki', Decimal('3.99')),
#  ('ARMY FLINTSTONES', 4, 'Pune', Decimal('3.99')),
#  ('ARMY FLINTSTONES', 4, 'Skikda', Decimal('6.99')),
#  ('ARTIST COLDBLOODED', 1, 'Ogbomosho', Decimal('6.99')),
#  ('ARTIST COLDBLOODED', 1, 'Rajkot', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', 2, 'Hamilton', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', 2, 'Myingyan', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', 2, 'Valencia', Decimal('3.99')),
#  ('ARTIST COLDBLOODED', 3, 'Funafuti', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', 3, 'Jastrzebie-Zdrj', Decimal('3.99')),
#  ('ARTIST COLDBLOODED', 3, 'Mosul', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', 3, 'Tafuna', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', 4, 'Ashdod', Decimal('6.99')),
#  ('ARTIST COLDBLOODED', 4, 'Bijapur', Decimal('5.99')),
#  ('ARTIST COLDBLOODED', 4, 'Duisburg', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', 4, 'Juazeiro do Norte', Decimal('6.99')),
#  ('ARTIST COLDBLOODED', 4, 'Lubumbashi', Decimal('5.99')),
#  ('ARTIST COLDBLOODED', 4, 'Nha Trang', Decimal('4.99')),
#  ('ARTIST COLDBLOODED', 4, 'Zaria', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 1, 's-Hertogenbosch', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 1, 'Sivas', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 2, 'Balurghat', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 2, 'Beni-Mellal', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 2, 'Fuzhou', Decimal('5.99')),
#  ('ATLANTIS CAUSE', 3, 'al-Manama', Decimal('5.99')),
#  ('ATLANTIS CAUSE', 3, 'Brockton', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 3, 'Caracas', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 3, 'Emmen', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 3, 'guas Lindas de Gois', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 3, 'Jodhpur', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 3, 'Sambhal', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 3, 'Sogamoso', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 3, 'Tabriz', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 3, 'Tanauan', Decimal('5.99')),
#  ('ATLANTIS CAUSE', 4, 'Abu Dhabi', Decimal('3.99')),
#  ('ATLANTIS CAUSE', 4, 'Ashgabat', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 4, 'Deba Habe', Decimal('5.99')),
#  ('ATLANTIS CAUSE', 4, 'Duisburg', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 4, 'Jining', Decimal('3.99')),
#  ('ATLANTIS CAUSE', 4, 'Klerksdorp', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 4, 'Pontianak', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 4, 'Pudukkottai', Decimal('3.99')),
#  ('ATLANTIS CAUSE', 4, 'Xiangfan', Decimal('3.99')),
#  ('ATTACKS HATE', 2, 'Sasebo', Decimal('4.99')),
#  ('ATTACKS HATE', 2, 'Yangor', Decimal('7.99')),
#  ('ATTACKS HATE', 3, 'Aden', Decimal('7.99')),
#  ('ATTACKS HATE', 3, 'Antofagasta', Decimal('8.99')),
#  ('ATTACKS HATE', 3, 'Banjul', Decimal('8.99')),
#  ('ATTACKS HATE', 3, 'Ife', Decimal('4.99')),
#  ('ATTACKS HATE', 3, 'Munger (Monghyr)', Decimal('4.99')),
#  ('ATTACKS HATE', 3, 'Owo', Decimal('5.99')),
#  ('ATTACKS HATE', 4, 'Ashdod', Decimal('5.99')),
#  ('ATTACKS HATE', 4, 'Bern', Decimal('4.99')),
#  ('ATTACKS HATE', 4, 'Carmen', Decimal('4.99')),
#  ('ATTACKS HATE', 4, 'Ipoh', Decimal('4.99')),
#  ('ATTACKS HATE', 4, 'Matsue', Decimal('5.99')),
#  ('ATTACKS HATE', 4, 'Sumy', Decimal('8.99')),
#  ('ATTACKS HATE', 4, 'Tangail', Decimal('5.99')),
#  ('ATTACKS HATE', 4, 'Ueda', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 1, 'Sincelejo', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 2, 'Ezhou', Decimal('7.99')),
#  ('ATTRACTION NEWTON', 2, 'Lengshuijiang', Decimal('6.99')),
#  ('ATTRACTION NEWTON', 2, 'Nagaon', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 2, 'Portoviejo', Decimal('8.99')),
#  ('ATTRACTION NEWTON', 2, 'Tete', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 3, 'Changzhou', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 3, 'Jakarta', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 3, 'Kimberley', Decimal('8.99')),
#  ('ATTRACTION NEWTON', 3, 'Mit Ghamr', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 3, 'Monywa', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 3, 'Mukateve', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 3, 'Patiala', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 3, 'Salzburg', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 3, 'Southend-on-Sea', Decimal('6.99')),
#  ('ATTRACTION NEWTON', 3, 'Zapopan', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 4, 'Akishima', Decimal('7.99')),
#  ('ATTRACTION NEWTON', 4, 'Amroha', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 4, 'Batna', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 4, 'Fontana', Decimal('5.99')),
#  ('ATTRACTION NEWTON', 4, 'Maikop', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 4, 'Maracabo', Decimal('8.99')),
#  ('ATTRACTION NEWTON', 4, 'Tongliao', Decimal('5.99')),
#  ('ATTRACTION NEWTON', 4, 'Zeleznogorsk', Decimal('7.99')),
#  ('AUTUMN CROW', 1, 'Ashgabat', Decimal('9.99')),
#  ('AUTUMN CROW', 2, 'Iwakuni', Decimal('6.99')),
#  ('AUTUMN CROW', 2, 'Stockport', Decimal('10.99')),
#  ('AUTUMN CROW', 3, 'Basel', Decimal('9.99')),
#  ('AUTUMN CROW', 3, 'Blumenau', Decimal('9.99')),
#  ('AUTUMN CROW', 3, 'Touliu', Decimal('5.99')),
#  ('AUTUMN CROW', 4, 'Aparecida de Goinia', Decimal('4.99')),
#  ('AUTUMN CROW', 4, 'Dallas', Decimal('4.99')),
#  ('AUTUMN CROW', 4, 'Fontana', Decimal('9.99')),
#  ('AUTUMN CROW', 4, 'Sincelejo', Decimal('4.99')),
#  ('AUTUMN CROW', 4, 'Tanshui', Decimal('5.99')),
#  ('BABY HALL', 1, 'Novoterkassk', Decimal('4.99')),
#  ('BABY HALL', 2, 'Memphis', Decimal('5.99')),
#  ('BABY HALL', 3, 'Lilongwe', Decimal('4.99')),
#  ('BABY HALL', 3, 'Osmaniye', Decimal('4.99')),
#  ('BABY HALL', 3, 'San Juan Bautista Tuxtepec', Decimal('4.99')),
#  ('BABY HALL', 4, 'Ilorin', Decimal('6.99')),
#  ('BABY HALL', 4, 'Lincoln', Decimal('4.99')),
#  ('BABY HALL', 4, 'Surakarta', Decimal('7.99')),
#  ('BACKLASH UNDEFEATED', 1, 'Kaliningrad', Decimal('5.99')),
#  ('BACKLASH UNDEFEATED', 1, 'Kamyin', Decimal('4.99')),
#  ('BACKLASH UNDEFEATED', 1, 'Maring', Decimal('6.99')),
#  ('BACKLASH UNDEFEATED', 2, 'Bellevue', Decimal('9.99')),
#  ('BACKLASH UNDEFEATED', 2, 'Cuauhtmoc', Decimal('9.99')),
#  ('BACKLASH UNDEFEATED', 2, 'Jedda', Decimal('4.99')),
#  ('BACKLASH UNDEFEATED', 2, 'Springs', Decimal('4.99')),
#  ('BACKLASH UNDEFEATED', 3, 'Blumenau', Decimal('10.99')),
#  ('BACKLASH UNDEFEATED', 3, 'Etawah', Decimal('9.99')),
#  ('BACKLASH UNDEFEATED', 3, 'Kursk', Decimal('9.99')),
#  ('BACKLASH UNDEFEATED', 3, 'London', Decimal('9.99')),
#  ('BACKLASH UNDEFEATED', 4, 'Elista', Decimal('8.99')),
#  ('BACKLASH UNDEFEATED', 4, 'Escobar', Decimal('8.99')),
#  ('BACKLASH UNDEFEATED', 4, 'Loja', Decimal('9.99')),
#  ('BACKLASH UNDEFEATED', 4, 'Omdurman', Decimal('8.99')),
#  ('BACKLASH UNDEFEATED', 4, 'Pontianak', Decimal('8.99')),
#  ('BACKLASH UNDEFEATED', 4, 'Tarlac', Decimal('7.99')),
#  ('BACKLASH UNDEFEATED', 4, 'Uijongbu', Decimal('5.99')),
#  ('BACKLASH UNDEFEATED', 4, 'Uttarpara-Kotrung', Decimal('9.99')),
#  ('BADMAN DAWN', 2, 'Huixquilucan', Decimal('2.99')),
#  ('BADMAN DAWN', 2, 'Rizhao', Decimal('2.99')),
#  ('BADMAN DAWN', 2, 'Tanza', Decimal('5.99')),
#  ('BADMAN DAWN', 2, 'Tieli', Decimal('4.99')),
#  ('BADMAN DAWN', 3, 'Alvorada', Decimal('2.99')),
#  ('BADMAN DAWN', 3, 'Fukuyama', Decimal('2.99')),
#  ('BADMAN DAWN', 3, 'Hami', Decimal('5.99')),
#  ('BADMAN DAWN', 3, 'Najafabad', Decimal('2.99')),
#  ('BADMAN DAWN', 3, 'Simferopol', Decimal('3.99')),
#  ('BADMAN DAWN', 3, 'Soshanguve', Decimal('2.99')),
#  ('BADMAN DAWN', 4, 'Abha', Decimal('2.99')),
#  ('BADMAN DAWN', 4, 'Balikesir', Decimal('2.99')),
#  ('BADMAN DAWN', 4, 'Beira', Decimal('4.99')),
#  ('BADMAN DAWN', 4, 'Citt del Vaticano', Decimal('3.99')),
#  ('BADMAN DAWN', 4, 'Oyo', Decimal('2.99')),
#  ('BADMAN DAWN', 4, 'Ozamis', Decimal('2.99')),
#  ('BADMAN DAWN', 4, 'Pak Kret', Decimal('6.98')),
#  ('BADMAN DAWN', 4, 'Serpuhov', Decimal('2.99')),
#  ('BADMAN DAWN', 4, 'Siliguri (Shiliguri)', Decimal('2.99')),
#  ('BADMAN DAWN', 4, 'Zaoyang', Decimal('3.99')),
#  ('BAKED CLEOPATRA', 1, 'Okayama', Decimal('2.99')),
#  ('BAKED CLEOPATRA', 2, 'Tarsus', Decimal('2.99')),
#  ('BAKED CLEOPATRA', 3, 'Garden Grove', Decimal('5.99')),
#  ('BAKED CLEOPATRA', 3, 'Hiroshima', Decimal('3.99')),
#  ('BAKED CLEOPATRA', 3, 'Madiun', Decimal('2.99')),
#  ('BAKED CLEOPATRA', 3, 'Santa Rosa', Decimal('6.99')),
#  ('BAKED CLEOPATRA', 4, 'Acua', Decimal('4.99')),
#  ('BAKED CLEOPATRA', 4, 'Bergamo', Decimal('6.99')),
#  ('BAKED CLEOPATRA', 4, 'Gandhinagar', Decimal('2.99')),
#  ('BAKED CLEOPATRA', 4, 'Hodeida', Decimal('6.99')),
#  ('BAKED CLEOPATRA', 4, 'Ourense (Orense)', Decimal('6.99')),
#  ('BAKED CLEOPATRA', 4, 'Phnom Penh', Decimal('2.99')),
#  ('BAKED CLEOPATRA', 4, 'San Miguel de Tucumn', Decimal('2.99')),
#  ('BAKED CLEOPATRA', 4, 'Valencia', Decimal('7.99')),
#  ('BAKED CLEOPATRA', 4, 'Vila Velha', Decimal('7.99')),
#  ('BAKED CLEOPATRA', 5, 'Haiphong', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 1, 'Witten', Decimal('6.99')),
#  ('BALLOON HOMEWARD', 2, 'Botosani', Decimal('3.99')),
#  ('BALLOON HOMEWARD', 2, 'Datong', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 2, 'Pak Kret', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 2, 'Plock', Decimal('3.99')),
#  ('BALLOON HOMEWARD', 2, 'Vitria de Santo Anto', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 3, 'Allende', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 3, 'Araatuba', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 3, 'Binzhou', Decimal('6.99')),
#  ('BALLOON HOMEWARD', 3, 'Cianjur', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 3, 'Fuyu', Decimal('3.99')),
#  ('BALLOON HOMEWARD', 3, 'Livorno', Decimal('3.99')),
#  ('BALLOON HOMEWARD', 3, 'Salzburg', Decimal('6.99')),
#  ('BALLOON HOMEWARD', 3, 'Udaipur', Decimal('5.99')),
#  ('BALLOON HOMEWARD', 3, 'Zaoyang', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 4, 'Beira', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 4, 'Beni-Mellal', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 4, 'Bucuresti', Decimal('6.99')),
#  ('BALLOON HOMEWARD', 4, 'Junan', Decimal('4.99')),
#  ('BALLOON HOMEWARD', 4, 'Roanoke', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 4, 'Yantai', Decimal('3.99')),
#  ('BALLOON HOMEWARD', 4, 'Yerevan', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 4, 'Yinchuan', Decimal('6.99')),
#  ('BALLROOM MOCKINGBIRD', 1, 'Valparai', Decimal('0.99')),
#  ('BALLROOM MOCKINGBIRD', 2, 'Compton', Decimal('0.99')),
#  ('BALLROOM MOCKINGBIRD', 3, 'Cam Ranh', Decimal('0.99')),
#  ('BALLROOM MOCKINGBIRD', 3, 'Omiya', Decimal('0.99')),
#  ('BALLROOM MOCKINGBIRD', 3, 'Tychy', Decimal('1.99')),
#  ('BALLROOM MOCKINGBIRD', 4, 'Effon-Alaiye', Decimal('0.99')),
#  ('BALLROOM MOCKINGBIRD', 4, 'Malm', Decimal('2.99')),
#  ('BALLROOM MOCKINGBIRD', 4, 'Tarsus', Decimal('0.99')),
#  ('BANG KWAI', 2, 'Torren', Decimal('3.99')),
#  ('BANG KWAI', 3, 'Coatzacoalcos', Decimal('3.99')),
#  ('BANG KWAI', 3, 'Pontianak', Decimal('2.99')),
#  ('BANG KWAI', 4, 'Boa Vista', Decimal('2.99')),
#  ('BANG KWAI', 4, 'Nagaon', Decimal('2.99')),
#  ('BANG KWAI', 4, 'Shikarpur', Decimal('2.99')),
#  ('BANG KWAI', 5, 'Taizz', Decimal('2.99')),
#  ('BANGER PINOCCHIO', 1, 'Shubra al-Khayma', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 1, 'Tonghae', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 2, 'Cabuyao', Decimal('1.99')),
#  ('BANGER PINOCCHIO', 2, 'Cavite', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 2, 'Munger (Monghyr)', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 2, 'Novoterkassk', Decimal('2.99')),
#  ('BANGER PINOCCHIO', 2, 'Siliguri (Shiliguri)', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 3, 'Abha', Decimal('1.99')),
#  ('BANGER PINOCCHIO', 3, 'Binzhou', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 3, 'Emeishan', Decimal('2.99')),
#  ('BANGER PINOCCHIO', 3, 'Kaduna', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 3, 'Ocumare del Tuy', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 3, 'Simferopol', Decimal('4.99')),
#  ('BANGER PINOCCHIO', 3, 'Tama', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 4, 'Almirante Brown', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 4, 'Bamenda', Decimal('2.99')),
#  ('BANGER PINOCCHIO', 4, 'Jakarta', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 4, 'Jinchang', Decimal('4.99')),
#  ('BANGER PINOCCHIO', 4, 'Katihar', Decimal('3.99')),
#  ('BANGER PINOCCHIO', 4, 'Tychy', Decimal('2.99')),
#  ('BANGER PINOCCHIO', 4, 'Vancouver', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 4, 'Vicente Lpez', Decimal('0.99')),
#  ('BARBARELLA STREETCAR', 1, 'Alvorada', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 1, 'Bucuresti', Decimal('5.99')),
#  ('BARBARELLA STREETCAR', 1, 'Kamakura', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 2, 'Ashdod', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 2, 'Cuernavaca', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 2, 'Ezeiza', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 2, 'Graz', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 2, 'Uruapan', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 3, 'Abha', Decimal('4.99')),
#  ('BARBARELLA STREETCAR', 3, 'Bellevue', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 3, 'Gandhinagar', Decimal('3.99')),
#  ('BARBARELLA STREETCAR', 3, 'Huixquilucan', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 3, 'Ikerre', Decimal('3.99')),
#  ('BARBARELLA STREETCAR', 3, 'Maring', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 3, 'Richmond Hill', Decimal('4.99')),
#  ('BARBARELLA STREETCAR', 3, 'Sal', Decimal('5.99')),
#  ('BARBARELLA STREETCAR', 3, 'Yuncheng', Decimal('5.99')),
#  ('BARBARELLA STREETCAR', 4, 'Hubli-Dharwad', Decimal('3.99')),
#  ('BARBARELLA STREETCAR', 4, 'Meixian', Decimal('5.99')),
#  ('BARBARELLA STREETCAR', 4, 'Miraj', Decimal('3.99')),
#  ('BARBARELLA STREETCAR', 4, 'Moscow', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 4, 'Niznekamsk', Decimal('3.99')),
#  ('BARBARELLA STREETCAR', 4, 'Qomsheh', Decimal('3.99')),
#  ('BARBARELLA STREETCAR', 4, 'South Hill', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 4, 'Tabriz', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 1, 'Juazeiro do Norte', Decimal('6.99')),
#  ('BAREFOOT MANCHURIAN', 2, 'Halifax', Decimal('4.99')),
#  ('BAREFOOT MANCHURIAN', 2, 'Jelets', Decimal('3.99')),
#  ('BAREFOOT MANCHURIAN', 2, 'Madiun', Decimal('3.99')),
#  ('BAREFOOT MANCHURIAN', 3, 'Basel', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 3, 'Fukuyama', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 3, 'Halisahar', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 3, 'Kuwana', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 3, 'Pontianak', Decimal('5.99')),
#  ('BAREFOOT MANCHURIAN', 3, 'Torren', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 4, 'Adoni', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 4, 'al-Manama', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 4, 'Guadalajara', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 4, 'Haiphong', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 4, 'Jastrzebie-Zdrj', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 4, 'Kitwe', Decimal('4.99')),
#  ('BAREFOOT MANCHURIAN', 4, 'Le Mans', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 4, 'Ljubertsy', Decimal('2.99')),
#  ('BASIC EASY', 1, 'Tianjin', Decimal('2.99')),
#  ('BASIC EASY', 2, 'Shimoga', Decimal('2.99')),
#  ('BASIC EASY', 2, 'Sincelejo', Decimal('2.99')),
#  ('BASIC EASY', 3, 'Akishima', Decimal('3.99')),
#  ('BASIC EASY', 3, 'Bayugan', Decimal('5.99')),
#  ('BASIC EASY', 3, 'Escobar', Decimal('7.99')),
#  ('BASIC EASY', 3, 'Jurez', Decimal('3.99')),
#  ('BASIC EASY', 3, 'Konotop', Decimal('2.99')),
#  ('BASIC EASY', 3, 'Santiago de Compostela', Decimal('2.99')),
#  ('BASIC EASY', 3, 'Vancouver', Decimal('5.99')),
#  ('BASIC EASY', 3, 'Ziguinchor', Decimal('2.99')),
#  ('BASIC EASY', 4, 'Batman', Decimal('3.99')),
#  ('BASIC EASY', 4, 'Haining', Decimal('2.99')),
#  ('BASIC EASY', 4, 'Imus', Decimal('2.99')),
#  ('BASIC EASY', 4, 'Lubumbashi', Decimal('6.99')),
#  ('BASIC EASY', 4, 'Novi Sad', Decimal('2.99')),
#  ('BASIC EASY', 4, 'Pjatigorsk', Decimal('2.99')),
#  ('BASIC EASY', 4, 'Robamba', Decimal('3.99')),
#  ('BASIC EASY', 4, 'Santa Rosa', Decimal('7.99')),
#  ('BASIC EASY', 4, 'Simferopol', Decimal('6.99')),
#  ('BASIC EASY', 5, 'Laohekou', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 1, 'Almirante Brown', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 1, 'Katihar', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 2, 'Cuautla', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 2, 'Kilis', Decimal('4.99')),
#  ('BEACH HEARTBREAKERS', 2, 'Novoterkassk', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 3, 'Bijapur', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 3, 'Caracas', Decimal('4.99')),
#  ('BEACH HEARTBREAKERS', 3, 'Crdoba', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 3, 'Hsichuh', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 3, 'Quilmes', Decimal('3.99')),
#  ('BEACH HEARTBREAKERS', 3, 'Sterling Heights', Decimal('5.99')),
#  ('BEACH HEARTBREAKERS', 4, 'Kingstown', Decimal('5.99')),
#  ('BEACH HEARTBREAKERS', 4, 'Lungtan', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 4, 'Mysore', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 4, 'Pathankot', Decimal('5.99')),
#  ('BEACH HEARTBREAKERS', 4, 'Ruse', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 4, 'Xiangtan', Decimal('2.99')),
#  ('BEAR GRACELAND', 1, 'Pingxiang', Decimal('3.99')),
#  ('BEAR GRACELAND', 1, 'Tabuk', Decimal('6.99')),
#  ('BEAR GRACELAND', 1, 'Uijongbu', Decimal('2.99')),
#  ('BEAR GRACELAND', 2, 'Bchar', Decimal('2.99')),
#  ('BEAR GRACELAND', 2, 'Bhopal', Decimal('2.99')),
#  ('BEAR GRACELAND', 2, 'Nakhon Sawan', Decimal('5.99')),
#  ('BEAR GRACELAND', 2, 'South Hill', Decimal('2.99')),
#  ('BEAR GRACELAND', 3, 'Angra dos Reis', Decimal('7.99')),
#  ('BEAR GRACELAND', 3, 'Juazeiro do Norte', Decimal('7.99')),
#  ('BEAR GRACELAND', 3, 'Olomouc', Decimal('3.99')),
#  ('BEAR GRACELAND', 3, 'Pune', Decimal('5.99')),
#  ('BEAR GRACELAND', 3, 'Rio Claro', Decimal('4.99')),
#  ('BEAR GRACELAND', 3, 'Robamba', Decimal('6.99')),
#  ('BEAR GRACELAND', 3, 'Tiefa', Decimal('3.99')),
#  ('BEAR GRACELAND', 4, 'Addis Abeba', Decimal('2.99')),
#  ('BEAR GRACELAND', 4, 'Ahmadnagar', Decimal('6.99')),
#  ('BEAR GRACELAND', 4, 'Bhilwara', Decimal('2.99')),
#  ('BEAR GRACELAND', 4, 'Czestochowa', Decimal('4.99')),
#  ('BEAR GRACELAND', 4, 'Lapu-Lapu', Decimal('4.99')),
#  ('BEAR GRACELAND', 4, 'Liaocheng', Decimal('7.99')),
#  ('BEAR GRACELAND', 4, 'Mardan', Decimal('2.99')),
#  ('BEAR GRACELAND', 4, 'Shenzhen', Decimal('2.99')),
#  ('BEAST HUNCHBACK', 1, 'Jinzhou', Decimal('6.99')),
#  ('BEAST HUNCHBACK', 2, 'Faaa', Decimal('4.99')),
#  ('BEAST HUNCHBACK', 2, 'Nanyang', Decimal('4.99')),
#  ('BEAST HUNCHBACK', 3, 'Duisburg', Decimal('4.99')),
#  ('BEAST HUNCHBACK', 3, 'Omiya', Decimal('10.99')),
#  ('BEAST HUNCHBACK', 3, 'Sincelejo', Decimal('8.99')),
#  ('BEAST HUNCHBACK', 4, 'Chandrapur', Decimal('4.99')),
#  ('BEAST HUNCHBACK', 4, 'Chiayi', Decimal('4.99')),
#  ('BEAST HUNCHBACK', 4, 'Guadalajara', Decimal('10.99')),
#  ('BEAST HUNCHBACK', 4, 'Kolpino', Decimal('7.99')),
#  ('BEAST HUNCHBACK', 4, 'Zaoyang', Decimal('5.99')),
#  ('BEAUTY GREASE', 1, 'Denizli', Decimal('6.99')),
#  ('BEAUTY GREASE', 2, 'Barcelona', Decimal('4.99')),
#  ('BEAUTY GREASE', 2, 'Daugavpils', Decimal('8.99')),
#  ('BEAUTY GREASE', 2, 'Huixquilucan', Decimal('4.99')),
#  ('BEAUTY GREASE', 3, 'Davao', Decimal('4.99')),
#  ('BEAUTY GREASE', 3, 'Firozabad', Decimal('4.99')),
#  ('BEAUTY GREASE', 3, 'Jaffna', Decimal('4.99')),
#  ('BEAUTY GREASE', 3, 'Kursk', Decimal('8.99')),
#  ('BEAUTY GREASE', 3, 'Lancaster', Decimal('8.99')),
#  ('BEAUTY GREASE', 3, 'Mwene-Ditu', Decimal('5.99')),
#  ('BEAUTY GREASE', 3, 'Richmond Hill', Decimal('4.99')),
#  ('BEAUTY GREASE', 3, 'Ziguinchor', Decimal('4.99')),
#  ('BEAUTY GREASE', 4, 'Acua', Decimal('4.99')),
#  ('BEAUTY GREASE', 4, 'Arlington', Decimal('4.99')),
#  ('BEAUTY GREASE', 4, 'Bhopal', Decimal('4.99')),
#  ('BEAUTY GREASE', 4, 'Dhule (Dhulia)', Decimal('7.99')),
#  ('BEAUTY GREASE', 4, 'Hsichuh', Decimal('4.99')),
#  ('BEAUTY GREASE', 4, 'Kamarhati', Decimal('6.99')),
#  ('BEAUTY GREASE', 4, 'Nezahualcyotl', Decimal('6.99')),
#  ('BEAUTY GREASE', 4, 'Omdurman', Decimal('4.99')),
#  ('BEAUTY GREASE', 4, 'Syktyvkar', Decimal('5.99')),
#  ('BEAUTY GREASE', 4, 'Zhezqazghan', Decimal('4.99')),
#  ('BED HIGHBALL', 3, 'Bhimavaram', Decimal('3.99')),
#  ('BED HIGHBALL', 3, 'Liaocheng', Decimal('2.99')),
#  ('BED HIGHBALL', 3, 'San Miguel de Tucumn', Decimal('2.99')),
#  ('BED HIGHBALL', 4, 'Iligan', Decimal('2.99')),
#  ('BED HIGHBALL', 4, 'Kursk', Decimal('5.99')),
#  ('BED HIGHBALL', 4, 'Santo Andr', Decimal('5.99')),
#  ('BEDAZZLED MARRIED', 1, 'Angra dos Reis', Decimal('1.99')),
#  ('BEDAZZLED MARRIED', 2, 'Balurghat', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 2, 'Myingyan', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 3, 'Baybay', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 3, 'Duisburg', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 3, 'Le Mans', Decimal('1.99')),
#  ('BEDAZZLED MARRIED', 3, 'Naju', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 3, 'San Felipe de Puerto Plata', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 4, 'al-Manama', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 4, 'Binzhou', Decimal('1.99')),
#  ('BEDAZZLED MARRIED', 4, 'Naju', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 4, 'Serpuhov', Decimal('0.99')),
#  ...]

# %%
# %%time
# %%sql
SELECT f.title, EXTRACT(month FROM p.payment_date) as month, ci.city, sum(p.amount) as revenue
FROM payment p
JOIN rental r    ON ( p.rental_id = r.rental_id )
JOIN inventory i ON ( r.inventory_id = i.inventory_id )
JOIN film f ON ( i.film_id = f.film_id)
JOIN customer c  ON ( p.customer_id = c.customer_id )
JOIN address a ON ( c.address_id = a.address_id )
JOIN city ci ON ( a.city_id = ci.city_id )
group by (f.title, month, ci.city)
order by f.title, month, ci.city, revenue desc;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 15992 rows affected.
# CPU times: total: 62.5 ms
# Wall time: 253 ms
# [('ACADEMY DINOSAUR', Decimal('1'), 'Celaya', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', Decimal('1'), 'Cianjur', Decimal('1.99')),
#  ('ACADEMY DINOSAUR', Decimal('2'), 'San Lorenzo', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', Decimal('2'), 'Sullana', Decimal('1.99')),
#  ('ACADEMY DINOSAUR', Decimal('2'), 'Udaipur', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', Decimal('3'), 'Almirante Brown', Decimal('1.99')),
#  ('ACADEMY DINOSAUR', Decimal('3'), 'Goinia', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', Decimal('3'), 'Kaliningrad', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', Decimal('3'), 'Kurashiki', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', Decimal('3'), 'Livorno', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', Decimal('3'), 'Nukualofa', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', Decimal('3'), 'Rajkot', Decimal('3.99')),
#  ('ACADEMY DINOSAUR', Decimal('3'), 'Sivas', Decimal('3.99')),
#  ('ACADEMY DINOSAUR', Decimal('3'), 'Tabriz', Decimal('3.99')),
#  ('ACADEMY DINOSAUR', Decimal('4'), 'Charlotte Amalie', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', Decimal('4'), 'Hamilton', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', Decimal('4'), 'Jos Azueta', Decimal('1.99')),
#  ('ACADEMY DINOSAUR', Decimal('4'), 'Lipetsk', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', Decimal('4'), 'London', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', Decimal('4'), 'Pjatigorsk', Decimal('1.99')),
#  ('ACADEMY DINOSAUR', Decimal('4'), 'Sucre', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', Decimal('4'), 'Tel Aviv-Jaffa', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', Decimal('4'), 'Vila Velha', Decimal('0.99')),
#  ('ACE GOLDFINGER', Decimal('3'), 'Binzhou', Decimal('8.99')),
#  ('ACE GOLDFINGER', Decimal('3'), 'Kumbakonam', Decimal('4.99')),
#  ('ACE GOLDFINGER', Decimal('3'), 'Pereira', Decimal('8.99')),
#  ('ACE GOLDFINGER', Decimal('3'), 'Touliu', Decimal('9.99')),
#  ('ACE GOLDFINGER', Decimal('4'), 'Simferopol', Decimal('9.99')),
#  ('ACE GOLDFINGER', Decimal('4'), 'Soshanguve', Decimal('4.99')),
#  ('ACE GOLDFINGER', Decimal('5'), 'Balikesir', Decimal('4.99')),
#  ('ADAPTATION HOLES', Decimal('1'), 'Shikarpur', Decimal('2.99')),
#  ('ADAPTATION HOLES', Decimal('2'), 'Jelets', Decimal('2.99')),
#  ('ADAPTATION HOLES', Decimal('3'), 'al-Qatif', Decimal('2.99')),
#  ('ADAPTATION HOLES', Decimal('3'), 'Cayenne', Decimal('2.99')),
#  ('ADAPTATION HOLES', Decimal('3'), 'Coacalco de Berriozbal', Decimal('2.99')),
#  ('ADAPTATION HOLES', Decimal('3'), 'Salinas', Decimal('2.99')),
#  ('ADAPTATION HOLES', Decimal('3'), 'Santa Brbara dOeste', Decimal('2.99')),
#  ('ADAPTATION HOLES', Decimal('3'), 'Sasebo', Decimal('4.99')),
#  ('ADAPTATION HOLES', Decimal('4'), 'Jodhpur', Decimal('2.99')),
#  ('ADAPTATION HOLES', Decimal('4'), 'Miraj', Decimal('2.99')),
#  ('ADAPTATION HOLES', Decimal('4'), 'Ogbomosho', Decimal('2.99')),
#  ('ADAPTATION HOLES', Decimal('4'), 'Urawa', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', Decimal('1'), 'Hidalgo', Decimal('3.99')),
#  ('AFFAIR PREJUDICE', Decimal('1'), 'Tuguegarao', Decimal('3.99')),
#  ('AFFAIR PREJUDICE', Decimal('2'), 'Changzhou', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', Decimal('2'), 'Crdoba', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', Decimal('3'), 'Aparecida de Goinia', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', Decimal('3'), 'Atinsk', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', Decimal('3'), 'Avellaneda', Decimal('6.99')),
#  ('AFFAIR PREJUDICE', Decimal('3'), 'Caracas', Decimal('6.99')),
#  ('AFFAIR PREJUDICE', Decimal('3'), 'Laiwu', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', Decimal('3'), 'Rancagua', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', Decimal('4'), 'Chiayi', Decimal('4.99')),
#  ('AFFAIR PREJUDICE', Decimal('4'), 'Ciomas', Decimal('5.99')),
#  ('AFFAIR PREJUDICE', Decimal('4'), 'Lublin', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', Decimal('4'), 'Malm', Decimal('5.99')),
#  ('AFFAIR PREJUDICE', Decimal('4'), 'Palghat (Palakkad)', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', Decimal('4'), 'Qomsheh', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', Decimal('4'), 's-Hertogenbosch', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', Decimal('4'), 'Saint-Denis', Decimal('3.99')),
#  ('AFFAIR PREJUDICE', Decimal('4'), 'San Felipe de Puerto Plata', Decimal('4.99')),
#  ('AFFAIR PREJUDICE', Decimal('4'), 'Sirjan', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', Decimal('4'), 'Sokoto', Decimal('4.99')),
#  ('AFFAIR PREJUDICE', Decimal('4'), 'Tiefa', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', Decimal('5'), 'Caracas', Decimal('2.99')),
#  ('AFRICAN EGG', Decimal('1'), 'Ivanovo', Decimal('3.99')),
#  ('AFRICAN EGG', Decimal('2'), 'Okayama', Decimal('3.99')),
#  ('AFRICAN EGG', Decimal('2'), 'Richmond Hill', Decimal('4.99')),
#  ('AFRICAN EGG', Decimal('3'), 'Rampur', Decimal('3.99')),
#  ('AFRICAN EGG', Decimal('3'), 'Smolensk', Decimal('4.99')),
#  ('AFRICAN EGG', Decimal('3'), 'Tokat', Decimal('2.99')),
#  ('AFRICAN EGG', Decimal('4'), 'Jedda', Decimal('4.99')),
#  ('AFRICAN EGG', Decimal('4'), 'Jhansi', Decimal('2.99')),
#  ('AFRICAN EGG', Decimal('4'), 'Kitwe', Decimal('4.99')),
#  ('AFRICAN EGG', Decimal('4'), 'Salzburg', Decimal('5.99')),
#  ('AFRICAN EGG', Decimal('4'), 'York', Decimal('4.99')),
#  ('AFRICAN EGG', Decimal('5'), 'al-Manama', Decimal('2.99')),
#  ('AGENT TRUMAN', Decimal('1'), 'Coatzacoalcos', Decimal('8.99')),
#  ('AGENT TRUMAN', Decimal('1'), 'Izumisano', Decimal('5.99')),
#  ('AGENT TRUMAN', Decimal('2'), 'Antofagasta', Decimal('3.99')),
#  ('AGENT TRUMAN', Decimal('2'), 'Moscow', Decimal('8.99')),
#  ('AGENT TRUMAN', Decimal('2'), 'Taizz', Decimal('6.99')),
#  ('AGENT TRUMAN', Decimal('3'), 'Bhilwara', Decimal('8.99')),
#  ('AGENT TRUMAN', Decimal('3'), 'Chisinau', Decimal('4.99')),
#  ('AGENT TRUMAN', Decimal('3'), 'Citrus Heights', Decimal('6.99')),
#  ('AGENT TRUMAN', Decimal('3'), 'Emeishan', Decimal('3.99')),
#  ('AGENT TRUMAN', Decimal('3'), 'Luzinia', Decimal('3.99')),
#  ('AGENT TRUMAN', Decimal('3'), 'Mogiljov', Decimal('6.99')),
#  ('AGENT TRUMAN', Decimal('3'), 'Omdurman', Decimal('7.99')),
#  ('AGENT TRUMAN', Decimal('3'), 'Sunnyvale', Decimal('4.99')),
#  ('AGENT TRUMAN', Decimal('3'), 'Usak', Decimal('7.99')),
#  ('AGENT TRUMAN', Decimal('4'), 'Aurora', Decimal('4.99')),
#  ('AGENT TRUMAN', Decimal('4'), 'Huixquilucan', Decimal('4.99')),
#  ('AGENT TRUMAN', Decimal('4'), 'Matsue', Decimal('5.99')),
#  ('AGENT TRUMAN', Decimal('4'), 'Nantou', Decimal('2.99')),
#  ('AGENT TRUMAN', Decimal('4'), 'Pontianak', Decimal('7.99')),
#  ('AGENT TRUMAN', Decimal('4'), 'Quilmes', Decimal('2.99')),
#  ('AGENT TRUMAN', Decimal('4'), 'Tafuna', Decimal('4.99')),
#  ('AIRPLANE SIERRA', Decimal('2'), 'Cavite', Decimal('7.99')),
#  ('AIRPLANE SIERRA', Decimal('2'), 'Lubumbashi', Decimal('4.99')),
#  ('AIRPLANE SIERRA', Decimal('3'), 'Ibirit', Decimal('4.99')),
#  ('AIRPLANE SIERRA', Decimal('3'), 'Iwakuni', Decimal('4.99')),
#  ('AIRPLANE SIERRA', Decimal('3'), 'Johannesburg', Decimal('7.99')),
#  ('AIRPLANE SIERRA', Decimal('3'), 'Jurez', Decimal('4.99')),
#  ('AIRPLANE SIERRA', Decimal('3'), 'Mahajanga', Decimal('5.99')),
#  ('AIRPLANE SIERRA', Decimal('3'), 's-Hertogenbosch', Decimal('4.99')),
#  ('AIRPLANE SIERRA', Decimal('4'), 'Bhusawal', Decimal('4.99')),
#  ('AIRPLANE SIERRA', Decimal('4'), 'Kuwana', Decimal('4.99')),
#  ('AIRPLANE SIERRA', Decimal('4'), 'Salamanca', Decimal('5.99')),
#  ('AIRPLANE SIERRA', Decimal('4'), 'Sincelejo', Decimal('4.99')),
#  ('AIRPLANE SIERRA', Decimal('4'), 'Tsuyama', Decimal('4.99')),
#  ('AIRPLANE SIERRA', Decimal('4'), 'Yuncheng', Decimal('4.99')),
#  ('AIRPLANE SIERRA', Decimal('4'), 'Zalantun', Decimal('4.99')),
#  ('AIRPORT POLLOCK', Decimal('1'), 'Okinawa', Decimal('5.99')),
#  ('AIRPORT POLLOCK', Decimal('1'), 'Pemalang', Decimal('4.99')),
#  ('AIRPORT POLLOCK', Decimal('1'), 'Taguig', Decimal('4.99')),
#  ('AIRPORT POLLOCK', Decimal('2'), 'Molodetno', Decimal('5.99')),
#  ('AIRPORT POLLOCK', Decimal('2'), 'Portoviejo', Decimal('6.99')),
#  ('AIRPORT POLLOCK', Decimal('2'), 'Vaduz', Decimal('4.99')),
#  ('AIRPORT POLLOCK', Decimal('3'), 'Augusta-Richmond County', Decimal('4.99')),
#  ('AIRPORT POLLOCK', Decimal('3'), 'Lilongwe', Decimal('7.99')),
#  ('AIRPORT POLLOCK', Decimal('3'), 'Lublin', Decimal('6.99')),
#  ('AIRPORT POLLOCK', Decimal('3'), 'Peoria', Decimal('5.99')),
#  ('AIRPORT POLLOCK', Decimal('3'), 'Yangor', Decimal('5.99')),
#  ('AIRPORT POLLOCK', Decimal('4'), 'Bamenda', Decimal('5.99')),
#  ('AIRPORT POLLOCK', Decimal('4'), 'Dhaka', Decimal('4.99')),
#  ('AIRPORT POLLOCK', Decimal('4'), 'Erlangen', Decimal('5.99')),
#  ('AIRPORT POLLOCK', Decimal('4'), 'Fukuyama', Decimal('4.99')),
#  ('AIRPORT POLLOCK', Decimal('4'), 'Palghat (Palakkad)', Decimal('4.99')),
#  ('AIRPORT POLLOCK', Decimal('4'), 'San Juan Bautista Tuxtepec', Decimal('4.99')),
#  ('AIRPORT POLLOCK', Decimal('4'), 'Sanaa', Decimal('4.99')),
#  ('ALABAMA DEVIL', Decimal('3'), 'Greensboro', Decimal('5.99')),
#  ('ALABAMA DEVIL', Decimal('3'), 'Halifax', Decimal('7.99')),
#  ('ALABAMA DEVIL', Decimal('3'), 'Otsu', Decimal('8.99')),
#  ('ALABAMA DEVIL', Decimal('3'), 'Sunnyvale', Decimal('2.99')),
#  ('ALABAMA DEVIL', Decimal('3'), 'Zaoyang', Decimal('5.99')),
#  ('ALABAMA DEVIL', Decimal('4'), 'Arlington', Decimal('8.99')),
#  ('ALABAMA DEVIL', Decimal('4'), 'Asuncin', Decimal('5.99')),
#  ('ALABAMA DEVIL', Decimal('4'), 'Changhwa', Decimal('4.99')),
#  ('ALABAMA DEVIL', Decimal('4'), 'Eskisehir', Decimal('2.99')),
#  ('ALABAMA DEVIL', Decimal('4'), 'Kanazawa', Decimal('4.99')),
#  ('ALABAMA DEVIL', Decimal('4'), 'Mit Ghamr', Decimal('2.99')),
#  ('ALABAMA DEVIL', Decimal('4'), 'Probolinggo', Decimal('8.99')),
#  ('ALADDIN CALENDAR', Decimal('2'), 'Kaduna', Decimal('4.99')),
#  ('ALADDIN CALENDAR', Decimal('2'), 'Kisumu', Decimal('4.99')),
#  ('ALADDIN CALENDAR', Decimal('2'), 'La Plata', Decimal('4.99')),
#  ('ALADDIN CALENDAR', Decimal('2'), 'Olomouc', Decimal('4.99')),
#  ('ALADDIN CALENDAR', Decimal('3'), 'Adoni', Decimal('6.99')),
#  ('ALADDIN CALENDAR', Decimal('3'), 'Balaiha', Decimal('6.99')),
#  ('ALADDIN CALENDAR', Decimal('3'), 'Coacalco de Berriozbal', Decimal('4.99')),
#  ('ALADDIN CALENDAR', Decimal('3'), 'Deba Habe', Decimal('4.99')),
#  ('ALADDIN CALENDAR', Decimal('3'), 'Dos Quebradas', Decimal('4.99')),
#  ('ALADDIN CALENDAR', Decimal('3'), 'Halisahar', Decimal('4.99')),
#  ('ALADDIN CALENDAR', Decimal('3'), 'Mwanza', Decimal('4.99')),
#  ('ALADDIN CALENDAR', Decimal('3'), 'Ranchi', Decimal('4.99')),
#  ('ALADDIN CALENDAR', Decimal('3'), 'Sogamoso', Decimal('7.99')),
#  ('ALADDIN CALENDAR', Decimal('3'), 'Zalantun', Decimal('4.99')),
#  ('ALADDIN CALENDAR', Decimal('4'), 'Effon-Alaiye', Decimal('4.99')),
#  ('ALADDIN CALENDAR', Decimal('4'), 'Esfahan', Decimal('4.99')),
#  ('ALADDIN CALENDAR', Decimal('4'), 'Gulbarga', Decimal('7.99')),
#  ('ALADDIN CALENDAR', Decimal('4'), 'Hodeida', Decimal('4.99')),
#  ('ALADDIN CALENDAR', Decimal('4'), 'Izumisano', Decimal('7.99')),
#  ('ALADDIN CALENDAR', Decimal('4'), 'Monclova', Decimal('4.99')),
#  ('ALADDIN CALENDAR', Decimal('4'), 'Okinawa', Decimal('4.99')),
#  ('ALADDIN CALENDAR', Decimal('4'), 'Stockport', Decimal('5.99')),
#  ('ALADDIN CALENDAR', Decimal('4'), 'Valencia', Decimal('7.99')),
#  ('ALAMO VIDEOTAPE', Decimal('1'), 'Arecibo', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', Decimal('1'), 'Yuzhou', Decimal('3.99')),
#  ('ALAMO VIDEOTAPE', Decimal('2'), 'Meixian', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', Decimal('2'), 'Rio Claro', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', Decimal('2'), 'Tarlac', Decimal('1.99')),
#  ('ALAMO VIDEOTAPE', Decimal('3'), 'Baicheng', Decimal('1.99')),
#  ('ALAMO VIDEOTAPE', Decimal('3'), 'Bat Yam', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', Decimal('3'), 'Ife', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', Decimal('3'), 'Jinchang', Decimal('1.99')),
#  ('ALAMO VIDEOTAPE', Decimal('3'), 'Myingyan', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', Decimal('3'), 'Papeete', Decimal('1.99')),
#  ('ALAMO VIDEOTAPE', Decimal('3'), 'Pudukkottai', Decimal('3.99')),
#  ('ALAMO VIDEOTAPE', Decimal('3'), 'Stara Zagora', Decimal('1.99')),
#  ('ALAMO VIDEOTAPE', Decimal('3'), 'Tanauan', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', Decimal('4'), 'Berhampore (Baharampur)', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', Decimal('4'), 'Duisburg', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', Decimal('4'), 'Emmen', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', Decimal('4'), 'Grand Prairie', Decimal('1.99')),
#  ('ALAMO VIDEOTAPE', Decimal('4'), 'Idfu', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', Decimal('4'), 'Lapu-Lapu', Decimal('1.98')),
#  ('ALAMO VIDEOTAPE', Decimal('4'), 'Owo', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', Decimal('4'), 'Pemalang', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', Decimal('4'), 'Zeleznogorsk', Decimal('0.99')),
#  ('ALASKA PHANTOM', Decimal('1'), 'Nezahualcyotl', Decimal('0.99')),
#  ('ALASKA PHANTOM', Decimal('1'), 'Zhezqazghan', Decimal('2.99')),
#  ('ALASKA PHANTOM', Decimal('2'), 'al-Qadarif', Decimal('0.99')),
#  ('ALASKA PHANTOM', Decimal('2'), 'Braslia', Decimal('2.99')),
#  ('ALASKA PHANTOM', Decimal('2'), 'Maring', Decimal('0.99')),
#  ('ALASKA PHANTOM', Decimal('2'), 'Sterling Heights', Decimal('1.99')),
#  ('ALASKA PHANTOM', Decimal('2'), 'Touliu', Decimal('0.99')),
#  ('ALASKA PHANTOM', Decimal('3'), 'Dhule (Dhulia)', Decimal('2.99')),
#  ('ALASKA PHANTOM', Decimal('3'), 'Laohekou', Decimal('1.99')),
#  ('ALASKA PHANTOM', Decimal('3'), 'Nabereznyje Telny', Decimal('0.99')),
#  ('ALASKA PHANTOM', Decimal('3'), 'Nantou', Decimal('0.99')),
#  ('ALASKA PHANTOM', Decimal('3'), 'Peoria', Decimal('3.99')),
#  ('ALASKA PHANTOM', Decimal('3'), 'Saint Louis', Decimal('0.99')),
#  ('ALASKA PHANTOM', Decimal('3'), 'Szkesfehrvr', Decimal('1.99')),
#  ('ALASKA PHANTOM', Decimal('3'), 'Zhezqazghan', Decimal('0.99')),
#  ('ALASKA PHANTOM', Decimal('4'), 'al-Hawiya', Decimal('0.99')),
#  ('ALASKA PHANTOM', Decimal('4'), 'Baicheng', Decimal('0.99')),
#  ('ALASKA PHANTOM', Decimal('4'), 'Bhilwara', Decimal('3.99')),
#  ('ALASKA PHANTOM', Decimal('4'), 'Dhule (Dhulia)', Decimal('0.99')),
#  ('ALASKA PHANTOM', Decimal('4'), 'Lhokseumawe', Decimal('1.99')),
#  ('ALASKA PHANTOM', Decimal('4'), 'Ljubertsy', Decimal('0.99')),
#  ('ALASKA PHANTOM', Decimal('4'), 'Mandi Bahauddin', Decimal('0.99')),
#  ('ALASKA PHANTOM', Decimal('4'), 'Niznekamsk', Decimal('2.99')),
#  ('ALASKA PHANTOM', Decimal('4'), 'Omdurman', Decimal('0.99')),
#  ('ALASKA PHANTOM', Decimal('4'), 'Tiefa', Decimal('0.99')),
#  ('ALASKA PHANTOM', Decimal('4'), 'Xiangtan', Decimal('1.99')),
#  ('ALI FOREVER', Decimal('3'), 'Esfahan', Decimal('5.99')),
#  ('ALI FOREVER', Decimal('3'), 'Lubumbashi', Decimal('4.99')),
#  ('ALI FOREVER', Decimal('3'), 'Ourense (Orense)', Decimal('9.99')),
#  ('ALI FOREVER', Decimal('3'), 'Sharja', Decimal('4.99')),
#  ('ALI FOREVER', Decimal('4'), 'Cuauhtmoc', Decimal('7.99')),
#  ('ALI FOREVER', Decimal('4'), 'Jakarta', Decimal('4.99')),
#  ('ALI FOREVER', Decimal('4'), 'Maikop', Decimal('5.99')),
#  ('ALI FOREVER', Decimal('4'), 'Vaduz', Decimal('4.99')),
#  ('ALI FOREVER', Decimal('5'), 'Huixquilucan', Decimal('4.99')),
#  ('ALIEN CENTER', Decimal('1'), 'Caracas', Decimal('2.99')),
#  ('ALIEN CENTER', Decimal('1'), 'Escobar', Decimal('2.99')),
#  ('ALIEN CENTER', Decimal('2'), 'Baiyin', Decimal('2.99')),
#  ('ALIEN CENTER', Decimal('2'), 'Lengshuijiang', Decimal('2.99')),
#  ('ALIEN CENTER', Decimal('2'), 'Rancagua', Decimal('4.99')),
#  ('ALIEN CENTER', Decimal('3'), 'Bag', Decimal('2.99')),
#  ('ALIEN CENTER', Decimal('3'), 'Hsichuh', Decimal('2.99')),
#  ('ALIEN CENTER', Decimal('3'), 'Huejutla de Reyes', Decimal('2.99')),
#  ('ALIEN CENTER', Decimal('3'), 'Kragujevac', Decimal('2.99')),
#  ('ALIEN CENTER', Decimal('3'), 'Memphis', Decimal('6.99')),
#  ('ALIEN CENTER', Decimal('3'), 'Nagareyama', Decimal('2.99')),
#  ('ALIEN CENTER', Decimal('3'), 'San Felipe de Puerto Plata', Decimal('5.99')),
#  ('ALIEN CENTER', Decimal('3'), 'Sanya', Decimal('4.99')),
#  ('ALIEN CENTER', Decimal('3'), 'Songkhla', Decimal('2.99')),
#  ('ALIEN CENTER', Decimal('4'), 'Cuman', Decimal('2.99')),
#  ('ALIEN CENTER', Decimal('4'), 'El Fuerte', Decimal('4.99')),
#  ('ALIEN CENTER', Decimal('4'), 'Emeishan', Decimal('6.99')),
#  ('ALIEN CENTER', Decimal('4'), 'Juazeiro do Norte', Decimal('3.99')),
#  ('ALIEN CENTER', Decimal('4'), 'Richmond Hill', Decimal('2.99')),
#  ('ALIEN CENTER', Decimal('4'), 'Shahr-e Kord', Decimal('2.99')),
#  ('ALIEN CENTER', Decimal('4'), 'Xiangfan', Decimal('6.99')),
#  ('ALIEN CENTER', Decimal('4'), 'Zhezqazghan', Decimal('5.99')),
#  ('ALLEY EVOLUTION', Decimal('1'), 'Najafabad', Decimal('5.99')),
#  ('ALLEY EVOLUTION', Decimal('2'), 'Lancaster', Decimal('2.99')),
#  ('ALLEY EVOLUTION', Decimal('2'), 'Mexicali', Decimal('6.99')),
#  ('ALLEY EVOLUTION', Decimal('3'), 'Aden', Decimal('4.99')),
#  ('ALLEY EVOLUTION', Decimal('3'), 'Jos Azueta', Decimal('2.99')),
#  ('ALLEY EVOLUTION', Decimal('3'), 'Kalisz', Decimal('2.99')),
#  ('ALLEY EVOLUTION', Decimal('3'), 'Ponce', Decimal('2.99')),
#  ('ALLEY EVOLUTION', Decimal('3'), 'Shahr-e Kord', Decimal('2.99')),
#  ('ALLEY EVOLUTION', Decimal('3'), 'Tuguegarao', Decimal('2.99')),
#  ('ALLEY EVOLUTION', Decimal('4'), 'Esfahan', Decimal('2.99')),
#  ('ALLEY EVOLUTION', Decimal('4'), 'NDjamna', Decimal('2.99')),
#  ('ALLEY EVOLUTION', Decimal('4'), 'Shikarpur', Decimal('2.99')),
#  ('ALLEY EVOLUTION', Decimal('4'), 'Tonghae', Decimal('4.99')),
#  ('ALLEY EVOLUTION', Decimal('4'), 'Tsaotun', Decimal('2.99')),
#  ('ALONE TRIP', Decimal('1'), 'Arak', Decimal('0.99')),
#  ('ALONE TRIP', Decimal('2'), 'Almirante Brown', Decimal('0.99')),
#  ('ALONE TRIP', Decimal('2'), 'Tuguegarao', Decimal('3.99')),
#  ('ALONE TRIP', Decimal('3'), 'Kamjanets-Podilskyi', Decimal('3.99')),
#  ('ALONE TRIP', Decimal('3'), 'Lungtan', Decimal('2.99')),
#  ('ALONE TRIP', Decimal('3'), 'NDjamna', Decimal('0.99')),
#  ('ALONE TRIP', Decimal('3'), 'Sincelejo', Decimal('2.99')),
#  ('ALONE TRIP', Decimal('3'), 'Sousse', Decimal('4.99')),
#  ('ALONE TRIP', Decimal('3'), 'Sterling Heights', Decimal('4.99')),
#  ('ALONE TRIP', Decimal('3'), 'Tarsus', Decimal('2.99')),
#  ('ALONE TRIP', Decimal('3'), 'Vinh', Decimal('1.99')),
#  ('ALONE TRIP', Decimal('4'), 'Arecibo', Decimal('1.99')),
#  ('ALONE TRIP', Decimal('4'), 'Cabuyao', Decimal('1.99')),
#  ('ALONE TRIP', Decimal('4'), 'Hami', Decimal('6.99')),
#  ('ALONE TRIP', Decimal('4'), 'Huixquilucan', Decimal('4.99')),
#  ('ALONE TRIP', Decimal('4'), 'Mwanza', Decimal('6.99')),
#  ('ALONE TRIP', Decimal('4'), 'Syktyvkar', Decimal('6.99')),
#  ('ALONE TRIP', Decimal('5'), 'Tanza', Decimal('0.99')),
#  ('ALTER VICTORY', Decimal('1'), 'Ezhou', Decimal('0.99')),
#  ('ALTER VICTORY', Decimal('1'), 'Vinh', Decimal('0.99')),
#  ('ALTER VICTORY', Decimal('2'), 'Charlotte Amalie', Decimal('0.99')),
#  ('ALTER VICTORY', Decimal('2'), 'Cianjur', Decimal('0.99')),
#  ('ALTER VICTORY', Decimal('2'), 'Purnea (Purnia)', Decimal('0.99')),
#  ('ALTER VICTORY', Decimal('3'), 'Alessandria', Decimal('0.99')),
#  ('ALTER VICTORY', Decimal('3'), 'Bijapur', Decimal('0.99')),
#  ('ALTER VICTORY', Decimal('3'), 'Kamyin', Decimal('0.99')),
#  ('ALTER VICTORY', Decimal('3'), 'Korolev', Decimal('0.99')),
#  ('ALTER VICTORY', Decimal('3'), 'Meixian', Decimal('0.99')),
#  ('ALTER VICTORY', Decimal('3'), 'Tongliao', Decimal('1.99')),
#  ('ALTER VICTORY', Decimal('4'), 'Addis Abeba', Decimal('1.99')),
#  ('ALTER VICTORY', Decimal('4'), 'Avellaneda', Decimal('0.99')),
#  ('ALTER VICTORY', Decimal('4'), 'Bandar Seri Begawan', Decimal('0.99')),
#  ('ALTER VICTORY', Decimal('4'), 'Boksburg', Decimal('0.99')),
#  ('ALTER VICTORY', Decimal('4'), 'Kitwe', Decimal('3.99')),
#  ('ALTER VICTORY', Decimal('4'), 'Nantou', Decimal('0.99')),
#  ('ALTER VICTORY', Decimal('4'), 'Shaoguan', Decimal('3.99')),
#  ('ALTER VICTORY', Decimal('4'), 'Shimonoseki', Decimal('0.99')),
#  ('ALTER VICTORY', Decimal('4'), 'Sirjan', Decimal('3.99')),
#  ('ALTER VICTORY', Decimal('4'), 'Tiefa', Decimal('0.99')),
#  ('ALTER VICTORY', Decimal('4'), 'Urawa', Decimal('0.99')),
#  ('AMADEUS HOLY', Decimal('1'), 'La Plata', Decimal('0.99')),
#  ('AMADEUS HOLY', Decimal('2'), 'Denizli', Decimal('0.99')),
#  ('AMADEUS HOLY', Decimal('2'), 'Jakarta', Decimal('0.99')),
#  ('AMADEUS HOLY', Decimal('2'), 'Kurashiki', Decimal('0.99')),
#  ('AMADEUS HOLY', Decimal('2'), 'Myingyan', Decimal('0.99')),
#  ('AMADEUS HOLY', Decimal('3'), 'Araatuba', Decimal('0.99')),
#  ('AMADEUS HOLY', Decimal('3'), 'Citt del Vaticano', Decimal('1.99')),
#  ('AMADEUS HOLY', Decimal('3'), 'Joliet', Decimal('3.99')),
#  ('AMADEUS HOLY', Decimal('3'), 'Laredo', Decimal('0.99')),
#  ('AMADEUS HOLY', Decimal('3'), 'Matamoros', Decimal('0.99')),
#  ('AMADEUS HOLY', Decimal('3'), 'Shubra al-Khayma', Decimal('3.99')),
#  ('AMADEUS HOLY', Decimal('3'), 'Vila Velha', Decimal('0.99')),
#  ('AMADEUS HOLY', Decimal('4'), 'Arak', Decimal('0.99')),
#  ('AMADEUS HOLY', Decimal('4'), 'Bilbays', Decimal('1.99')),
#  ('AMADEUS HOLY', Decimal('4'), 'Hohhot', Decimal('1.99')),
#  ('AMADEUS HOLY', Decimal('4'), 'Jining', Decimal('0.99')),
#  ('AMADEUS HOLY', Decimal('4'), 'Nabereznyje Telny', Decimal('0.99')),
#  ('AMADEUS HOLY', Decimal('4'), 'Pjatigorsk', Decimal('0.99')),
#  ('AMADEUS HOLY', Decimal('4'), 'Poos de Caldas', Decimal('3.99')),
#  ('AMADEUS HOLY', Decimal('4'), 'Warren', Decimal('1.99')),
#  ('AMADEUS HOLY', Decimal('5'), 'London', Decimal('0.99')),
#  ('AMELIE HELLFIGHTERS', Decimal('2'), 'Acua', Decimal('4.99')),
#  ('AMELIE HELLFIGHTERS', Decimal('2'), 'Ipoh', Decimal('5.99')),
#  ('AMELIE HELLFIGHTERS', Decimal('3'), 'Anpolis', Decimal('4.99')),
#  ('AMELIE HELLFIGHTERS', Decimal('3'), 'Sterling Heights', Decimal('4.99')),
#  ('AMELIE HELLFIGHTERS', Decimal('3'), 'Tonghae', Decimal('8.99')),
#  ('AMELIE HELLFIGHTERS', Decimal('4'), 'Botshabelo', Decimal('5.99')),
#  ('AMELIE HELLFIGHTERS', Decimal('4'), 'Funafuti', Decimal('9.99')),
#  ('AMELIE HELLFIGHTERS', Decimal('4'), 'Madiun', Decimal('4.99')),
#  ('AMELIE HELLFIGHTERS', Decimal('4'), 'Meixian', Decimal('6.99')),
#  ('AMELIE HELLFIGHTERS', Decimal('4'), 'So Bernardo do Campo', Decimal('9.99')),
#  ('AMERICAN CIRCUS', Decimal('1'), 'Callao', Decimal('10.99')),
#  ('AMERICAN CIRCUS', Decimal('1'), 'Juazeiro do Norte', Decimal('4.99')),
#  ('AMERICAN CIRCUS', Decimal('2'), 'Dos Quebradas', Decimal('9.99')),
#  ('AMERICAN CIRCUS', Decimal('2'), 'El Fuerte', Decimal('6.99')),
#  ('AMERICAN CIRCUS', Decimal('2'), 'Oulu', Decimal('4.99')),
#  ('AMERICAN CIRCUS', Decimal('3'), 'Bayugan', Decimal('4.99')),
#  ('AMERICAN CIRCUS', Decimal('3'), 'Bergamo', Decimal('5.99')),
#  ('AMERICAN CIRCUS', Decimal('3'), 'Bijapur', Decimal('10.99')),
#  ('AMERICAN CIRCUS', Decimal('3'), 'Changhwa', Decimal('4.99')),
#  ('AMERICAN CIRCUS', Decimal('3'), 'Imus', Decimal('4.99')),
#  ('AMERICAN CIRCUS', Decimal('3'), 'Konotop', Decimal('10.99')),
#  ('AMERICAN CIRCUS', Decimal('3'), 'Nagaon', Decimal('4.99')),
#  ('AMERICAN CIRCUS', Decimal('3'), 'Oulu', Decimal('4.99')),
#  ('AMERICAN CIRCUS', Decimal('4'), 'Benguela', Decimal('9.99')),
#  ('AMERICAN CIRCUS', Decimal('4'), 'Bydgoszcz', Decimal('4.99')),
#  ('AMERICAN CIRCUS', Decimal('4'), 'Cabuyao', Decimal('8.99')),
#  ('AMERICAN CIRCUS', Decimal('4'), 'Halle/Saale', Decimal('8.99')),
#  ('AMERICAN CIRCUS', Decimal('4'), 'Juazeiro do Norte', Decimal('9.99')),
#  ('AMERICAN CIRCUS', Decimal('4'), 'Nador', Decimal('8.99')),
#  ('AMERICAN CIRCUS', Decimal('4'), 'Saint-Denis', Decimal('10.99')),
#  ('AMERICAN CIRCUS', Decimal('4'), 'Tiefa', Decimal('8.99')),
#  ('AMERICAN CIRCUS', Decimal('5'), 'Lipetsk', Decimal('4.99')),
#  ('AMISTAD MIDSUMMER', Decimal('2'), 'Akron', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', Decimal('2'), 'Mysore', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', Decimal('2'), 'Shimonoseki', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', Decimal('3'), 'Elista', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', Decimal('3'), 'Garland', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', Decimal('3'), 'Jastrzebie-Zdrj', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', Decimal('3'), 'Kolpino', Decimal('3.99')),
#  ('AMISTAD MIDSUMMER', Decimal('3'), 'Miyakonojo', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', Decimal('3'), 's-Hertogenbosch', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', Decimal('3'), 'Vijayawada', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', Decimal('3'), 'Zanzibar', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', Decimal('4'), 'Apeldoorn', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', Decimal('4'), 'Arecibo', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', Decimal('4'), 'Avellaneda', Decimal('4.99')),
#  ('AMISTAD MIDSUMMER', Decimal('4'), 'Cavite', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', Decimal('4'), 'Effon-Alaiye', Decimal('5.99')),
#  ('AMISTAD MIDSUMMER', Decimal('4'), 'Nantou', Decimal('3.99')),
#  ('AMISTAD MIDSUMMER', Decimal('4'), 'Sasebo', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', Decimal('4'), 'Usak', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', Decimal('4'), 'Xinxiang', Decimal('3.99')),
#  ('AMISTAD MIDSUMMER', Decimal('5'), 'Imus', Decimal('2.99')),
#  ('ANACONDA CONFESSIONS', Decimal('1'), 'Fengshan', Decimal('0.99')),
#  ('ANACONDA CONFESSIONS', Decimal('1'), 'Tarsus', Decimal('1.99')),
#  ('ANACONDA CONFESSIONS', Decimal('2'), 'Athenai', Decimal('6.99')),
#  ('ANACONDA CONFESSIONS', Decimal('2'), 'Dallas', Decimal('0.99')),
#  ('ANACONDA CONFESSIONS', Decimal('2'), 'Kermanshah', Decimal('1.99')),
#  ('ANACONDA CONFESSIONS', Decimal('2'), 'Nanyang', Decimal('3.99')),
#  ('ANACONDA CONFESSIONS', Decimal('2'), 'Otsu', Decimal('5.99')),
#  ('ANACONDA CONFESSIONS', Decimal('3'), 'Botshabelo', Decimal('0.99')),
#  ('ANACONDA CONFESSIONS', Decimal('3'), 'Haldia', Decimal('0.99')),
#  ('ANACONDA CONFESSIONS', Decimal('3'), 'Roanoke', Decimal('5.99')),
#  ('ANACONDA CONFESSIONS', Decimal('3'), 'Shanwei', Decimal('2.99')),
#  ('ANACONDA CONFESSIONS', Decimal('3'), 'Uttarpara-Kotrung', Decimal('0.99')),
#  ('ANACONDA CONFESSIONS', Decimal('4'), 'Batman', Decimal('5.99')),
#  ('ANACONDA CONFESSIONS', Decimal('4'), 'Caracas', Decimal('1.99')),
#  ('ANACONDA CONFESSIONS', Decimal('4'), 'Charlotte Amalie', Decimal('0.99')),
#  ('ANACONDA CONFESSIONS', Decimal('4'), 'Jelets', Decimal('1.99')),
#  ('ANACONDA CONFESSIONS', Decimal('4'), 'Molodetno', Decimal('3.99')),
#  ('ANACONDA CONFESSIONS', Decimal('4'), 'Sambhal', Decimal('2.99')),
#  ('ANACONDA CONFESSIONS', Decimal('4'), 'San Juan Bautista Tuxtepec', Decimal('2.99')),
#  ('ANACONDA CONFESSIONS', Decimal('4'), 'Tanza', Decimal('3.99')),
#  ('ANACONDA CONFESSIONS', Decimal('4'), 'Vitria de Santo Anto', Decimal('0.99')),
#  ('ANALYZE HOOSIERS', Decimal('2'), 'Saint Louis', Decimal('4.99')),
#  ('ANALYZE HOOSIERS', Decimal('2'), 'Xintai', Decimal('2.99')),
#  ('ANALYZE HOOSIERS', Decimal('2'), 'Yuncheng', Decimal('2.99')),
#  ('ANALYZE HOOSIERS', Decimal('3'), 'Bijapur', Decimal('3.99')),
#  ('ANALYZE HOOSIERS', Decimal('3'), 'Ciudad del Este', Decimal('2.99')),
#  ('ANALYZE HOOSIERS', Decimal('3'), 'Joliet', Decimal('2.99')),
#  ('ANALYZE HOOSIERS', Decimal('3'), 'Tartu', Decimal('4.99')),
#  ('ANALYZE HOOSIERS', Decimal('4'), 'Ambattur', Decimal('4.99')),
#  ('ANALYZE HOOSIERS', Decimal('4'), 'Celaya', Decimal('3.99')),
#  ('ANALYZE HOOSIERS', Decimal('4'), 'Citrus Heights', Decimal('4.99')),
#  ('ANALYZE HOOSIERS', Decimal('4'), 'Kurashiki', Decimal('5.99')),
#  ('ANALYZE HOOSIERS', Decimal('4'), 'Kuwana', Decimal('2.99')),
#  ('ANALYZE HOOSIERS', Decimal('4'), 'Usak', Decimal('2.99')),
#  ('ANALYZE HOOSIERS', Decimal('4'), 'Valparai', Decimal('3.99')),
#  ('ANGELS LIFE', Decimal('1'), 'Adana', Decimal('6.99')),
#  ('ANGELS LIFE', Decimal('1'), 'Salala', Decimal('8.99')),
#  ('ANGELS LIFE', Decimal('2'), 'Arecibo', Decimal('3.99')),
#  ('ANGELS LIFE', Decimal('2'), 'Kermanshah', Decimal('3.99')),
#  ('ANGELS LIFE', Decimal('2'), 'Urawa', Decimal('2.99')),
#  ('ANGELS LIFE', Decimal('3'), 'Fukuyama', Decimal('3.99')),
#  ('ANGELS LIFE', Decimal('3'), 'Greensboro', Decimal('2.99')),
#  ('ANGELS LIFE', Decimal('3'), 'Kakamigahara', Decimal('2.99')),
#  ('ANGELS LIFE', Decimal('3'), 'Nagareyama', Decimal('5.99')),
#  ('ANGELS LIFE', Decimal('3'), 'Salamanca', Decimal('8.99')),
#  ('ANGELS LIFE', Decimal('3'), 'San Juan Bautista Tuxtepec', Decimal('6.99')),
#  ('ANGELS LIFE', Decimal('3'), 'Teboksary', Decimal('6.99')),
#  ('ANGELS LIFE', Decimal('3'), 'Wroclaw', Decimal('7.99')),
#  ('ANGELS LIFE', Decimal('4'), 'Ambattur', Decimal('2.99')),
#  ('ANGELS LIFE', Decimal('4'), 'Augusta-Richmond County', Decimal('2.99')),
#  ('ANGELS LIFE', Decimal('4'), 'Carmen', Decimal('5.99')),
#  ('ANGELS LIFE', Decimal('4'), 'Kakamigahara', Decimal('3.99')),
#  ('ANGELS LIFE', Decimal('4'), 'Korolev', Decimal('7.99')),
#  ('ANGELS LIFE', Decimal('4'), 'Olomouc', Decimal('2.99')),
#  ('ANGELS LIFE', Decimal('4'), 'Rampur', Decimal('8.99')),
#  ('ANGELS LIFE', Decimal('4'), 'Sharja', Decimal('6.99')),
#  ('ANGELS LIFE', Decimal('4'), 'York', Decimal('2.99')),
#  ('ANNIE IDENTITY', Decimal('1'), 'Jedda', Decimal('3.99')),
#  ('ANNIE IDENTITY', Decimal('1'), 'Maring', Decimal('3.99')),
#  ('ANNIE IDENTITY', Decimal('1'), 'Tel Aviv-Jaffa', Decimal('0.99')),
#  ('ANNIE IDENTITY', Decimal('2'), 'Battambang', Decimal('2.99')),
#  ('ANNIE IDENTITY', Decimal('2'), 'Ede', Decimal('5.99')),
#  ('ANNIE IDENTITY', Decimal('2'), 'Goinia', Decimal('0.99')),
#  ('ANNIE IDENTITY', Decimal('2'), 'Tama', Decimal('0.99')),
#  ('ANNIE IDENTITY', Decimal('3'), 'Ashqelon', Decimal('4.99')),
#  ('ANNIE IDENTITY', Decimal('3'), 'Czestochowa', Decimal('4.99')),
#  ('ANNIE IDENTITY', Decimal('3'), 'Myingyan', Decimal('1.99')),
#  ('ANNIE IDENTITY', Decimal('3'), 'Pangkal Pinang', Decimal('0.99')),
#  ('ANNIE IDENTITY', Decimal('3'), 'Santa F', Decimal('2.99')),
#  ('ANNIE IDENTITY', Decimal('3'), 'Shaoguan', Decimal('6.99')),
#  ('ANNIE IDENTITY', Decimal('3'), 'Yuncheng', Decimal('0.99')),
#  ('ANNIE IDENTITY', Decimal('4'), 'Cabuyao', Decimal('0.99')),
#  ('ANNIE IDENTITY', Decimal('4'), 'Luzinia', Decimal('0.99')),
#  ('ANNIE IDENTITY', Decimal('4'), 'Oyo', Decimal('0.99')),
#  ('ANNIE IDENTITY', Decimal('4'), 'Szkesfehrvr', Decimal('0.99')),
#  ('ANNIE IDENTITY', Decimal('4'), 'Vilnius', Decimal('1.99')),
#  ('ANNIE IDENTITY', Decimal('4'), 'Zanzibar', Decimal('0.99')),
#  ('ANNIE IDENTITY', Decimal('4'), 'Zaria', Decimal('5.99')),
#  ('ANNIE IDENTITY', Decimal('4'), 'Zhoushan', Decimal('2.99')),
#  ('ANONYMOUS HUMAN', Decimal('2'), 'Uruapan', Decimal('1.99')),
#  ('ANONYMOUS HUMAN', Decimal('2'), 'Varanasi (Benares)', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', Decimal('3'), 'Basel', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', Decimal('3'), 'Ezhou', Decimal('2.99')),
#  ('ANONYMOUS HUMAN', Decimal('3'), 'Kowloon and New Kowloon', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', Decimal('3'), 'La Romana', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', Decimal('3'), 'San Bernardino', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', Decimal('3'), 'Zhezqazghan', Decimal('1.99')),
#  ('ANONYMOUS HUMAN', Decimal('4'), 'Dhaka', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', Decimal('4'), 'Iwakuni', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', Decimal('4'), 'Kamakura', Decimal('1.99')),
#  ('ANONYMOUS HUMAN', Decimal('4'), 'Liepaja', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', Decimal('4'), 'Richmond Hill', Decimal('0.99')),
#  ('ANTHEM LUKE', Decimal('1'), 'Lengshuijiang', Decimal('6.99')),
#  ('ANTHEM LUKE', Decimal('1'), 'Pyongyang', Decimal('4.99')),
#  ('ANTHEM LUKE', Decimal('1'), 'Uluberia', Decimal('4.99')),
#  ('ANTHEM LUKE', Decimal('2'), 'Ashgabat', Decimal('4.99')),
#  ('ANTHEM LUKE', Decimal('2'), 'Cuauhtmoc', Decimal('4.99')),
#  ('ANTHEM LUKE', Decimal('2'), 'San Felipe del Progreso', Decimal('4.99')),
#  ('ANTHEM LUKE', Decimal('3'), 'Acua', Decimal('4.99')),
#  ('ANTHEM LUKE', Decimal('3'), 'Fukuyama', Decimal('4.99')),
#  ('ANTHEM LUKE', Decimal('3'), 'Ozamis', Decimal('4.99')),
#  ('ANTHEM LUKE', Decimal('4'), 'Boa Vista', Decimal('8.99')),
#  ('ANTHEM LUKE', Decimal('4'), 'Changzhou', Decimal('4.99')),
#  ('ANTHEM LUKE', Decimal('4'), 'Coacalco de Berriozbal', Decimal('4.99')),
#  ('ANTHEM LUKE', Decimal('4'), 'Kirovo-Tepetsk', Decimal('4.99')),
#  ('ANTHEM LUKE', Decimal('4'), 'Kuwana', Decimal('5.99')),
#  ('ANTHEM LUKE', Decimal('4'), 'Lhokseumawe', Decimal('8.99')),
#  ('ANTITRUST TOMATOES', Decimal('1'), 'Erlangen', Decimal('2.99')),
#  ('ANTITRUST TOMATOES', Decimal('1'), 'Novoterkassk', Decimal('2.99')),
#  ('ANTITRUST TOMATOES', Decimal('2'), 'Lapu-Lapu', Decimal('6.99')),
#  ('ANTITRUST TOMATOES', Decimal('2'), 'Sharja', Decimal('3.99')),
#  ('ANTITRUST TOMATOES', Decimal('3'), 'Malm', Decimal('2.99')),
#  ('ANTITRUST TOMATOES', Decimal('3'), 'Pereira', Decimal('2.99')),
#  ('ANTITRUST TOMATOES', Decimal('4'), 'Bhimavaram', Decimal('3.99')),
#  ('ANTITRUST TOMATOES', Decimal('4'), 'Fuyu', Decimal('4.99')),
#  ('ANTITRUST TOMATOES', Decimal('4'), 'Vijayawada', Decimal('2.99')),
#  ('ANTITRUST TOMATOES', Decimal('4'), 'Ziguinchor', Decimal('2.99')),
#  ('ANYTHING SAVANNAH', Decimal('1'), 'Halle/Saale', Decimal('2.99')),
#  ('ANYTHING SAVANNAH', Decimal('2'), 'Araatuba', Decimal('4.99')),
#  ('ANYTHING SAVANNAH', Decimal('2'), 'Mexicali', Decimal('6.99')),
#  ('ANYTHING SAVANNAH', Decimal('3'), 'Cam Ranh', Decimal('3.99')),
#  ('ANYTHING SAVANNAH', Decimal('3'), 'El Monte', Decimal('5.99')),
#  ('ANYTHING SAVANNAH', Decimal('3'), 'Gandhinagar', Decimal('2.99')),
#  ('ANYTHING SAVANNAH', Decimal('3'), 'Yangor', Decimal('7.99')),
#  ('ANYTHING SAVANNAH', Decimal('4'), 'Banjul', Decimal('7.99')),
#  ('ANYTHING SAVANNAH', Decimal('4'), 'Zaoyang', Decimal('2.99')),
#  ('APACHE DIVINE', Decimal('1'), 'Cavite', Decimal('4.99')),
#  ('APACHE DIVINE', Decimal('1'), 'Mukateve', Decimal('7.99')),
#  ('APACHE DIVINE', Decimal('1'), 'So Leopoldo', Decimal('4.99')),
#  ('APACHE DIVINE', Decimal('2'), 'Bamenda', Decimal('4.99')),
#  ('APACHE DIVINE', Decimal('2'), 'Cam Ranh', Decimal('4.99')),
#  ('APACHE DIVINE', Decimal('2'), 'Iwaki', Decimal('4.99')),
#  ('APACHE DIVINE', Decimal('2'), 'Taizz', Decimal('4.99')),
#  ('APACHE DIVINE', Decimal('3'), 'Balikesir', Decimal('6.99')),
#  ('APACHE DIVINE', Decimal('3'), 'Boksburg', Decimal('7.99')),
#  ('APACHE DIVINE', Decimal('3'), 'El Fuerte', Decimal('6.99')),
#  ('APACHE DIVINE', Decimal('3'), 'Guadalajara', Decimal('4.99')),
#  ('APACHE DIVINE', Decimal('3'), 'Kanazawa', Decimal('4.99')),
#  ('APACHE DIVINE', Decimal('3'), 'Maikop', Decimal('5.99')),
#  ('APACHE DIVINE', Decimal('3'), 'Moscow', Decimal('5.99')),
#  ('APACHE DIVINE', Decimal('3'), 'Okinawa', Decimal('8.99')),
#  ('APACHE DIVINE', Decimal('3'), 'Sorocaba', Decimal('4.99')),
#  ('APACHE DIVINE', Decimal('3'), 'Urawa', Decimal('4.99')),
#  ('APACHE DIVINE', Decimal('3'), 'Zanzibar', Decimal('4.99')),
#  ('APACHE DIVINE', Decimal('4'), 'Bandar Seri Begawan', Decimal('4.99')),
#  ('APACHE DIVINE', Decimal('4'), 'Carmen', Decimal('4.99')),
#  ('APACHE DIVINE', Decimal('4'), 'Greensboro', Decimal('4.99')),
#  ('APACHE DIVINE', Decimal('4'), 'Jaffna', Decimal('4.99')),
#  ('APACHE DIVINE', Decimal('4'), 'Kimberley', Decimal('5.99')),
#  ('APACHE DIVINE', Decimal('4'), 'Malm', Decimal('4.99')),
#  ('APACHE DIVINE', Decimal('4'), 'Mit Ghamr', Decimal('6.99')),
#  ('APACHE DIVINE', Decimal('4'), 'Oshawa', Decimal('4.99')),
#  ('APACHE DIVINE', Decimal('4'), 'Pereira', Decimal('5.99')),
#  ('APACHE DIVINE', Decimal('4'), 'Robamba', Decimal('4.99')),
#  ('APACHE DIVINE', Decimal('4'), 'Taguig', Decimal('5.99')),
#  ('APACHE DIVINE', Decimal('4'), 'Tiefa', Decimal('4.99')),
#  ('APACHE DIVINE', Decimal('4'), 'York', Decimal('7.99')),
#  ('APOCALYPSE FLAMINGOS', Decimal('2'), 'Kalisz', Decimal('5.99')),
#  ('APOCALYPSE FLAMINGOS', Decimal('3'), 'Chandrapur', Decimal('4.99')),
#  ('APOCALYPSE FLAMINGOS', Decimal('3'), 'Ikerre', Decimal('4.99')),
#  ('APOCALYPSE FLAMINGOS', Decimal('4'), 'Belm', Decimal('4.99')),
#  ('APOCALYPSE FLAMINGOS', Decimal('4'), 'Blumenau', Decimal('4.99')),
#  ('APOCALYPSE FLAMINGOS', Decimal('4'), 'Ruse', Decimal('4.99')),
#  ('ARABIA DOGMA', Decimal('1'), 'Tartu', Decimal('0.99')),
#  ('ARABIA DOGMA', Decimal('2'), 'Qalyub', Decimal('0.99')),
#  ('ARABIA DOGMA', Decimal('2'), 'Toulouse', Decimal('0.99')),
#  ('ARABIA DOGMA', Decimal('3'), 'Amroha', Decimal('0.99')),
#  ('ARABIA DOGMA', Decimal('3'), 'La Plata', Decimal('3.99')),
#  ('ARABIA DOGMA', Decimal('3'), 'London', Decimal('3.99')),
#  ('ARABIA DOGMA', Decimal('3'), 'Lubumbashi', Decimal('0.99')),
#  ('ARABIA DOGMA', Decimal('3'), 'Monclova', Decimal('3.99')),
#  ('ARABIA DOGMA', Decimal('3'), 'Tokat', Decimal('1.99')),
#  ('ARABIA DOGMA', Decimal('4'), 'Changzhou', Decimal('0.99')),
#  ('ARABIA DOGMA', Decimal('4'), 'Lapu-Lapu', Decimal('0.99')),
#  ('ARABIA DOGMA', Decimal('4'), 'Tuguegarao', Decimal('0.99')),
#  ('ARABIA DOGMA', Decimal('4'), 'Usak', Decimal('0.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('2'), 'Arlington', Decimal('4.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('2'), 'Bhusawal', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('2'), 'Mwene-Ditu', Decimal('5.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('2'), 'Tonghae', Decimal('4.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('3'), 'Czestochowa', Decimal('6.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('3'), 'Higashiosaka', Decimal('3.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('3'), 'Kimberley', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('3'), 'Matsue', Decimal('3.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('3'), 'Ondo', Decimal('6.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('3'), 'Parbhani', Decimal('3.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('3'), 'Zalantun', Decimal('5.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('4'), 'Chapra', Decimal('6.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('4'), 'Dadu', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('4'), 'Fuyu', Decimal('3.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('4'), 'Gaziantep', Decimal('7.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('4'), 'Goinia', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('4'), 'Jamalpur', Decimal('4.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('4'), 'Kamakura', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('4'), 'Myingyan', Decimal('3.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('4'), 'Rio Claro', Decimal('3.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('4'), 'Roanoke', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('4'), 'Usak', Decimal('5.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('4'), 'Vicente Lpez', Decimal('7.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('4'), 'Zhezqazghan', Decimal('2.99')),
#  ('ARIZONA BANG', Decimal('2'), 'guas Lindas de Gois', Decimal('2.99')),
#  ('ARIZONA BANG', Decimal('2'), 'Jalib al-Shuyukh', Decimal('5.99')),
#  ('ARIZONA BANG', Decimal('2'), 'Szkesfehrvr', Decimal('2.99')),
#  ('ARIZONA BANG', Decimal('3'), 'Hamilton', Decimal('2.99')),
#  ('ARIZONA BANG', Decimal('3'), 'Kowloon and New Kowloon', Decimal('7.99')),
#  ('ARIZONA BANG', Decimal('3'), 'Molodetno', Decimal('4.99')),
#  ('ARIZONA BANG', Decimal('3'), 'Nantou', Decimal('2.99')),
#  ('ARIZONA BANG', Decimal('3'), 'Palghat (Palakkad)', Decimal('7.99')),
#  ('ARIZONA BANG', Decimal('3'), 'Pontianak', Decimal('4.99')),
#  ('ARIZONA BANG', Decimal('3'), 'Probolinggo', Decimal('2.99')),
#  ('ARIZONA BANG', Decimal('3'), 'Rajkot', Decimal('7.99')),
#  ('ARIZONA BANG', Decimal('3'), 'Salala', Decimal('2.99')),
#  ('ARIZONA BANG', Decimal('3'), 'Shikarpur', Decimal('4.99')),
#  ('ARIZONA BANG', Decimal('3'), 'Springs', Decimal('5.99')),
#  ('ARIZONA BANG', Decimal('3'), 'Vijayawada', Decimal('6.99')),
#  ('ARIZONA BANG', Decimal('4'), 'Battambang', Decimal('3.99')),
#  ('ARIZONA BANG', Decimal('4'), 'Davao', Decimal('4.99')),
#  ('ARIZONA BANG', Decimal('4'), 'Lancaster', Decimal('5.99')),
#  ('ARIZONA BANG', Decimal('4'), 'Liepaja', Decimal('7.99')),
#  ('ARIZONA BANG', Decimal('4'), 'Osmaniye', Decimal('2.99')),
#  ('ARIZONA BANG', Decimal('4'), 'Saint-Denis', Decimal('2.99')),
#  ('ARMAGEDDON LOST', Decimal('1'), 'Dallas', Decimal('3.99')),
#  ('ARMAGEDDON LOST', Decimal('2'), 'Surakarta', Decimal('4.99')),
#  ('ARMAGEDDON LOST', Decimal('2'), 'Tallahassee', Decimal('0.99')),
#  ('ARMAGEDDON LOST', Decimal('3'), 'Bhavnagar', Decimal('3.99')),
#  ('ARMAGEDDON LOST', Decimal('3'), 'Dzerzinsk', Decimal('5.99')),
#  ('ARMAGEDDON LOST', Decimal('3'), 'Hanoi', Decimal('1.99')),
#  ('ARMAGEDDON LOST', Decimal('3'), 'Nanyang', Decimal('0.99')),
#  ('ARMAGEDDON LOST', Decimal('3'), 'NDjamna', Decimal('0.99')),
#  ('ARMAGEDDON LOST', Decimal('3'), 'Rio Claro', Decimal('1.99')),
#  ('ARMAGEDDON LOST', Decimal('4'), 'Ambattur', Decimal('2.99')),
#  ('ARMAGEDDON LOST', Decimal('4'), 'Bradford', Decimal('0.99')),
#  ('ARMAGEDDON LOST', Decimal('4'), 'Cheju', Decimal('1.99')),
#  ('ARMAGEDDON LOST', Decimal('4'), 'Cianjur', Decimal('0.99')),
#  ('ARMAGEDDON LOST', Decimal('4'), 'Hiroshima', Decimal('2.99')),
#  ('ARMAGEDDON LOST', Decimal('4'), 'Luzinia', Decimal('0.99')),
#  ('ARMAGEDDON LOST', Decimal('4'), 'Nakhon Sawan', Decimal('0.99')),
#  ('ARMAGEDDON LOST', Decimal('4'), 'Rae Bareli', Decimal('3.99')),
#  ('ARMAGEDDON LOST', Decimal('4'), 'Saint-Denis', Decimal('0.99')),
#  ('ARMAGEDDON LOST', Decimal('4'), 'Szkesfehrvr', Decimal('0.99')),
#  ('ARMAGEDDON LOST', Decimal('4'), 'Uijongbu', Decimal('0.99')),
#  ('ARMAGEDDON LOST', Decimal('5'), 'Trshavn', Decimal('0.99')),
#  ('ARMY FLINTSTONES', Decimal('1'), 'Lublin', Decimal('0.99')),
#  ('ARMY FLINTSTONES', Decimal('1'), 'Sunnyvale', Decimal('3.99')),
#  ('ARMY FLINTSTONES', Decimal('2'), 'Kamarhati', Decimal('0.99')),
#  ('ARMY FLINTSTONES', Decimal('2'), 'Rae Bareli', Decimal('2.99')),
#  ('ARMY FLINTSTONES', Decimal('2'), 'Sterling Heights', Decimal('0.99')),
#  ('ARMY FLINTSTONES', Decimal('3'), 'Boa Vista', Decimal('0.99')),
#  ('ARMY FLINTSTONES', Decimal('3'), 'Lengshuijiang', Decimal('0.99')),
#  ('ARMY FLINTSTONES', Decimal('3'), 'Po', Decimal('3.99')),
#  ('ARMY FLINTSTONES', Decimal('3'), 'Yamuna Nagar', Decimal('0.99')),
#  ('ARMY FLINTSTONES', Decimal('3'), 'Yuzhou', Decimal('4.99')),
#  ('ARMY FLINTSTONES', Decimal('4'), 'Aden', Decimal('0.99')),
#  ('ARMY FLINTSTONES', Decimal('4'), 'Cavite', Decimal('0.99')),
#  ('ARMY FLINTSTONES', Decimal('4'), 'Jodhpur', Decimal('2.99')),
#  ('ARMY FLINTSTONES', Decimal('4'), 'Kurashiki', Decimal('3.99')),
#  ('ARMY FLINTSTONES', Decimal('4'), 'Pune', Decimal('3.99')),
#  ('ARMY FLINTSTONES', Decimal('4'), 'Skikda', Decimal('6.99')),
#  ('ARTIST COLDBLOODED', Decimal('1'), 'Ogbomosho', Decimal('6.99')),
#  ('ARTIST COLDBLOODED', Decimal('1'), 'Rajkot', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', Decimal('2'), 'Hamilton', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', Decimal('2'), 'Myingyan', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', Decimal('2'), 'Valencia', Decimal('3.99')),
#  ('ARTIST COLDBLOODED', Decimal('3'), 'Funafuti', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', Decimal('3'), 'Jastrzebie-Zdrj', Decimal('3.99')),
#  ('ARTIST COLDBLOODED', Decimal('3'), 'Mosul', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', Decimal('3'), 'Tafuna', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', Decimal('4'), 'Ashdod', Decimal('6.99')),
#  ('ARTIST COLDBLOODED', Decimal('4'), 'Bijapur', Decimal('5.99')),
#  ('ARTIST COLDBLOODED', Decimal('4'), 'Duisburg', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', Decimal('4'), 'Juazeiro do Norte', Decimal('6.99')),
#  ('ARTIST COLDBLOODED', Decimal('4'), 'Lubumbashi', Decimal('5.99')),
#  ('ARTIST COLDBLOODED', Decimal('4'), 'Nha Trang', Decimal('4.99')),
#  ('ARTIST COLDBLOODED', Decimal('4'), 'Zaria', Decimal('2.99')),
#  ('ATLANTIS CAUSE', Decimal('1'), 's-Hertogenbosch', Decimal('2.99')),
#  ('ATLANTIS CAUSE', Decimal('1'), 'Sivas', Decimal('2.99')),
#  ('ATLANTIS CAUSE', Decimal('2'), 'Balurghat', Decimal('2.99')),
#  ('ATLANTIS CAUSE', Decimal('2'), 'Beni-Mellal', Decimal('2.99')),
#  ('ATLANTIS CAUSE', Decimal('2'), 'Fuzhou', Decimal('5.99')),
#  ('ATLANTIS CAUSE', Decimal('3'), 'al-Manama', Decimal('5.99')),
#  ('ATLANTIS CAUSE', Decimal('3'), 'Brockton', Decimal('2.99')),
#  ('ATLANTIS CAUSE', Decimal('3'), 'Caracas', Decimal('2.99')),
#  ('ATLANTIS CAUSE', Decimal('3'), 'Emmen', Decimal('2.99')),
#  ('ATLANTIS CAUSE', Decimal('3'), 'guas Lindas de Gois', Decimal('2.99')),
#  ('ATLANTIS CAUSE', Decimal('3'), 'Jodhpur', Decimal('2.99')),
#  ('ATLANTIS CAUSE', Decimal('3'), 'Sambhal', Decimal('2.99')),
#  ('ATLANTIS CAUSE', Decimal('3'), 'Sogamoso', Decimal('2.99')),
#  ('ATLANTIS CAUSE', Decimal('3'), 'Tabriz', Decimal('2.99')),
#  ('ATLANTIS CAUSE', Decimal('3'), 'Tanauan', Decimal('5.99')),
#  ('ATLANTIS CAUSE', Decimal('4'), 'Abu Dhabi', Decimal('3.99')),
#  ('ATLANTIS CAUSE', Decimal('4'), 'Ashgabat', Decimal('2.99')),
#  ('ATLANTIS CAUSE', Decimal('4'), 'Deba Habe', Decimal('5.99')),
#  ('ATLANTIS CAUSE', Decimal('4'), 'Duisburg', Decimal('2.99')),
#  ('ATLANTIS CAUSE', Decimal('4'), 'Jining', Decimal('3.99')),
#  ('ATLANTIS CAUSE', Decimal('4'), 'Klerksdorp', Decimal('2.99')),
#  ('ATLANTIS CAUSE', Decimal('4'), 'Pontianak', Decimal('2.99')),
#  ('ATLANTIS CAUSE', Decimal('4'), 'Pudukkottai', Decimal('3.99')),
#  ('ATLANTIS CAUSE', Decimal('4'), 'Xiangfan', Decimal('3.99')),
#  ('ATTACKS HATE', Decimal('2'), 'Sasebo', Decimal('4.99')),
#  ('ATTACKS HATE', Decimal('2'), 'Yangor', Decimal('7.99')),
#  ('ATTACKS HATE', Decimal('3'), 'Aden', Decimal('7.99')),
#  ('ATTACKS HATE', Decimal('3'), 'Antofagasta', Decimal('8.99')),
#  ('ATTACKS HATE', Decimal('3'), 'Banjul', Decimal('8.99')),
#  ('ATTACKS HATE', Decimal('3'), 'Ife', Decimal('4.99')),
#  ('ATTACKS HATE', Decimal('3'), 'Munger (Monghyr)', Decimal('4.99')),
#  ('ATTACKS HATE', Decimal('3'), 'Owo', Decimal('5.99')),
#  ('ATTACKS HATE', Decimal('4'), 'Ashdod', Decimal('5.99')),
#  ('ATTACKS HATE', Decimal('4'), 'Bern', Decimal('4.99')),
#  ('ATTACKS HATE', Decimal('4'), 'Carmen', Decimal('4.99')),
#  ('ATTACKS HATE', Decimal('4'), 'Ipoh', Decimal('4.99')),
#  ('ATTACKS HATE', Decimal('4'), 'Matsue', Decimal('5.99')),
#  ('ATTACKS HATE', Decimal('4'), 'Sumy', Decimal('8.99')),
#  ('ATTACKS HATE', Decimal('4'), 'Tangail', Decimal('5.99')),
#  ('ATTACKS HATE', Decimal('4'), 'Ueda', Decimal('4.99')),
#  ('ATTRACTION NEWTON', Decimal('1'), 'Sincelejo', Decimal('4.99')),
#  ('ATTRACTION NEWTON', Decimal('2'), 'Ezhou', Decimal('7.99')),
#  ('ATTRACTION NEWTON', Decimal('2'), 'Lengshuijiang', Decimal('6.99')),
#  ('ATTRACTION NEWTON', Decimal('2'), 'Nagaon', Decimal('4.99')),
#  ('ATTRACTION NEWTON', Decimal('2'), 'Portoviejo', Decimal('8.99')),
#  ('ATTRACTION NEWTON', Decimal('2'), 'Tete', Decimal('4.99')),
#  ('ATTRACTION NEWTON', Decimal('3'), 'Changzhou', Decimal('4.99')),
#  ('ATTRACTION NEWTON', Decimal('3'), 'Jakarta', Decimal('4.99')),
#  ('ATTRACTION NEWTON', Decimal('3'), 'Kimberley', Decimal('8.99')),
#  ('ATTRACTION NEWTON', Decimal('3'), 'Mit Ghamr', Decimal('4.99')),
#  ('ATTRACTION NEWTON', Decimal('3'), 'Monywa', Decimal('4.99')),
#  ('ATTRACTION NEWTON', Decimal('3'), 'Mukateve', Decimal('4.99')),
#  ('ATTRACTION NEWTON', Decimal('3'), 'Patiala', Decimal('4.99')),
#  ('ATTRACTION NEWTON', Decimal('3'), 'Salzburg', Decimal('4.99')),
#  ('ATTRACTION NEWTON', Decimal('3'), 'Southend-on-Sea', Decimal('6.99')),
#  ('ATTRACTION NEWTON', Decimal('3'), 'Zapopan', Decimal('4.99')),
#  ('ATTRACTION NEWTON', Decimal('4'), 'Akishima', Decimal('7.99')),
#  ('ATTRACTION NEWTON', Decimal('4'), 'Amroha', Decimal('4.99')),
#  ('ATTRACTION NEWTON', Decimal('4'), 'Batna', Decimal('4.99')),
#  ('ATTRACTION NEWTON', Decimal('4'), 'Fontana', Decimal('5.99')),
#  ('ATTRACTION NEWTON', Decimal('4'), 'Maikop', Decimal('4.99')),
#  ('ATTRACTION NEWTON', Decimal('4'), 'Maracabo', Decimal('8.99')),
#  ('ATTRACTION NEWTON', Decimal('4'), 'Tongliao', Decimal('5.99')),
#  ('ATTRACTION NEWTON', Decimal('4'), 'Zeleznogorsk', Decimal('7.99')),
#  ('AUTUMN CROW', Decimal('1'), 'Ashgabat', Decimal('9.99')),
#  ('AUTUMN CROW', Decimal('2'), 'Iwakuni', Decimal('6.99')),
#  ('AUTUMN CROW', Decimal('2'), 'Stockport', Decimal('10.99')),
#  ('AUTUMN CROW', Decimal('3'), 'Basel', Decimal('9.99')),
#  ('AUTUMN CROW', Decimal('3'), 'Blumenau', Decimal('9.99')),
#  ('AUTUMN CROW', Decimal('3'), 'Touliu', Decimal('5.99')),
#  ('AUTUMN CROW', Decimal('4'), 'Aparecida de Goinia', Decimal('4.99')),
#  ('AUTUMN CROW', Decimal('4'), 'Dallas', Decimal('4.99')),
#  ('AUTUMN CROW', Decimal('4'), 'Fontana', Decimal('9.99')),
#  ('AUTUMN CROW', Decimal('4'), 'Sincelejo', Decimal('4.99')),
#  ('AUTUMN CROW', Decimal('4'), 'Tanshui', Decimal('5.99')),
#  ('BABY HALL', Decimal('1'), 'Novoterkassk', Decimal('4.99')),
#  ('BABY HALL', Decimal('2'), 'Memphis', Decimal('5.99')),
#  ('BABY HALL', Decimal('3'), 'Lilongwe', Decimal('4.99')),
#  ('BABY HALL', Decimal('3'), 'Osmaniye', Decimal('4.99')),
#  ('BABY HALL', Decimal('3'), 'San Juan Bautista Tuxtepec', Decimal('4.99')),
#  ('BABY HALL', Decimal('4'), 'Ilorin', Decimal('6.99')),
#  ('BABY HALL', Decimal('4'), 'Lincoln', Decimal('4.99')),
#  ('BABY HALL', Decimal('4'), 'Surakarta', Decimal('7.99')),
#  ('BACKLASH UNDEFEATED', Decimal('1'), 'Kaliningrad', Decimal('5.99')),
#  ('BACKLASH UNDEFEATED', Decimal('1'), 'Kamyin', Decimal('4.99')),
# ...
#  ('BADMAN DAWN', Decimal('3'), 'Simferopol', Decimal('3.99')),
#  ('BADMAN DAWN', Decimal('3'), 'Soshanguve', Decimal('2.99')),
#  ('BADMAN DAWN', Decimal('4'), 'Abha', Decimal('2.99')),
#  ('BADMAN DAWN', Decimal('4'), 'Balikesir', Decimal('2.99')),
#  ('BADMAN DAWN', Decimal('4'), 'Beira', Decimal('4.99')),
#  ('BADMAN DAWN', Decimal('4'), 'Citt del Vaticano', Decimal('3.99')),
#  ('BADMAN DAWN', Decimal('4'), 'Oyo', Decimal('2.99')),
#  ('BADMAN DAWN', Decimal('4'), 'Ozamis', Decimal('2.99')),
#  ('BADMAN DAWN', Decimal('4'), 'Pak Kret', Decimal('6.98')),
#  ('BADMAN DAWN', Decimal('4'), 'Serpuhov', Decimal('2.99')),
#  ('BADMAN DAWN', Decimal('4'), 'Siliguri (Shiliguri)', Decimal('2.99')),
#  ('BADMAN DAWN', Decimal('4'), 'Zaoyang', Decimal('3.99')),
#  ('BAKED CLEOPATRA', Decimal('1'), 'Okayama', Decimal('2.99')),
#  ('BAKED CLEOPATRA', Decimal('2'), 'Tarsus', Decimal('2.99')),
#  ('BAKED CLEOPATRA', Decimal('3'), 'Garden Grove', Decimal('5.99')),
#  ('BAKED CLEOPATRA', Decimal('3'), 'Hiroshima', Decimal('3.99')),
#  ('BAKED CLEOPATRA', Decimal('3'), 'Madiun', Decimal('2.99')),
#  ('BAKED CLEOPATRA', Decimal('3'), 'Santa Rosa', Decimal('6.99')),
#  ('BAKED CLEOPATRA', Decimal('4'), 'Acua', Decimal('4.99')),
#  ('BAKED CLEOPATRA', Decimal('4'), 'Bergamo', Decimal('6.99')),
#  ('BAKED CLEOPATRA', Decimal('4'), 'Gandhinagar', Decimal('2.99')),
#  ('BAKED CLEOPATRA', Decimal('4'), 'Hodeida', Decimal('6.99')),
#  ('BAKED CLEOPATRA', Decimal('4'), 'Ourense (Orense)', Decimal('6.99')),
#  ('BAKED CLEOPATRA', Decimal('4'), 'Phnom Penh', Decimal('2.99')),
#  ('BAKED CLEOPATRA', Decimal('4'), 'San Miguel de Tucumn', Decimal('2.99')),
#  ('BAKED CLEOPATRA', Decimal('4'), 'Valencia', Decimal('7.99')),
#  ('BAKED CLEOPATRA', Decimal('4'), 'Vila Velha', Decimal('7.99')),
#  ('BAKED CLEOPATRA', Decimal('5'), 'Haiphong', Decimal('2.99')),
#  ('BALLOON HOMEWARD', Decimal('1'), 'Witten', Decimal('6.99')),
#  ('BALLOON HOMEWARD', Decimal('2'), 'Botosani', Decimal('3.99')),
#  ('BALLOON HOMEWARD', Decimal('2'), 'Datong', Decimal('2.99')),
#  ('BALLOON HOMEWARD', Decimal('2'), 'Pak Kret', Decimal('2.99')),
#  ('BALLOON HOMEWARD', Decimal('2'), 'Plock', Decimal('3.99')),
#  ('BALLOON HOMEWARD', Decimal('2'), 'Vitria de Santo Anto', Decimal('2.99')),
#  ('BALLOON HOMEWARD', Decimal('3'), 'Allende', Decimal('2.99')),
#  ('BALLOON HOMEWARD', Decimal('3'), 'Araatuba', Decimal('2.99')),
#  ('BALLOON HOMEWARD', Decimal('3'), 'Binzhou', Decimal('6.99')),
#  ('BALLOON HOMEWARD', Decimal('3'), 'Cianjur', Decimal('2.99')),
#  ('BALLOON HOMEWARD', Decimal('3'), 'Fuyu', Decimal('3.99')),
#  ('BALLOON HOMEWARD', Decimal('3'), 'Livorno', Decimal('3.99')),
#  ('BALLOON HOMEWARD', Decimal('3'), 'Salzburg', Decimal('6.99')),
#  ('BALLOON HOMEWARD', Decimal('3'), 'Udaipur', Decimal('5.99')),
#  ('BALLOON HOMEWARD', Decimal('3'), 'Zaoyang', Decimal('2.99')),
#  ('BALLOON HOMEWARD', Decimal('4'), 'Beira', Decimal('2.99')),
#  ('BALLOON HOMEWARD', Decimal('4'), 'Beni-Mellal', Decimal('2.99')),
#  ('BALLOON HOMEWARD', Decimal('4'), 'Bucuresti', Decimal('6.99')),
#  ('BALLOON HOMEWARD', Decimal('4'), 'Junan', Decimal('4.99')),
#  ('BALLOON HOMEWARD', Decimal('4'), 'Roanoke', Decimal('2.99')),
#  ('BALLOON HOMEWARD', Decimal('4'), 'Yantai', Decimal('3.99')),
#  ('BALLOON HOMEWARD', Decimal('4'), 'Yerevan', Decimal('2.99')),
#  ('BALLOON HOMEWARD', Decimal('4'), 'Yinchuan', Decimal('6.99')),
#  ('BALLROOM MOCKINGBIRD', Decimal('1'), 'Valparai', Decimal('0.99')),
#  ('BALLROOM MOCKINGBIRD', Decimal('2'), 'Compton', Decimal('0.99')),
#  ('BALLROOM MOCKINGBIRD', Decimal('3'), 'Cam Ranh', Decimal('0.99')),
#  ('BALLROOM MOCKINGBIRD', Decimal('3'), 'Omiya', Decimal('0.99')),
#  ('BALLROOM MOCKINGBIRD', Decimal('3'), 'Tychy', Decimal('1.99')),
#  ('BALLROOM MOCKINGBIRD', Decimal('4'), 'Effon-Alaiye', Decimal('0.99')),
#  ('BALLROOM MOCKINGBIRD', Decimal('4'), 'Malm', Decimal('2.99')),
#  ('BALLROOM MOCKINGBIRD', Decimal('4'), 'Tarsus', Decimal('0.99')),
#  ('BANG KWAI', Decimal('2'), 'Torren', Decimal('3.99')),
#  ('BANG KWAI', Decimal('3'), 'Coatzacoalcos', Decimal('3.99')),
#  ('BANG KWAI', Decimal('3'), 'Pontianak', Decimal('2.99')),
#  ('BANG KWAI', Decimal('4'), 'Boa Vista', Decimal('2.99')),
#  ('BANG KWAI', Decimal('4'), 'Nagaon', Decimal('2.99')),
#  ('BANG KWAI', Decimal('4'), 'Shikarpur', Decimal('2.99')),
#  ('BANG KWAI', Decimal('5'), 'Taizz', Decimal('2.99')),
#  ('BANGER PINOCCHIO', Decimal('1'), 'Shubra al-Khayma', Decimal('0.99')),
#  ('BANGER PINOCCHIO', Decimal('1'), 'Tonghae', Decimal('0.99')),
#  ('BANGER PINOCCHIO', Decimal('2'), 'Cabuyao', Decimal('1.99')),
#  ('BANGER PINOCCHIO', Decimal('2'), 'Cavite', Decimal('0.99')),
#  ('BANGER PINOCCHIO', Decimal('2'), 'Munger (Monghyr)', Decimal('0.99')),
#  ('BANGER PINOCCHIO', Decimal('2'), 'Novoterkassk', Decimal('2.99')),
#  ('BANGER PINOCCHIO', Decimal('2'), 'Siliguri (Shiliguri)', Decimal('0.99')),
#  ('BANGER PINOCCHIO', Decimal('3'), 'Abha', Decimal('1.99')),
#  ('BANGER PINOCCHIO', Decimal('3'), 'Binzhou', Decimal('0.99')),
#  ('BANGER PINOCCHIO', Decimal('3'), 'Emeishan', Decimal('2.99')),
#  ('BANGER PINOCCHIO', Decimal('3'), 'Kaduna', Decimal('0.99')),
#  ('BANGER PINOCCHIO', Decimal('3'), 'Ocumare del Tuy', Decimal('0.99')),
#  ('BANGER PINOCCHIO', Decimal('3'), 'Simferopol', Decimal('4.99')),
#  ('BANGER PINOCCHIO', Decimal('3'), 'Tama', Decimal('0.99')),
#  ('BANGER PINOCCHIO', Decimal('4'), 'Almirante Brown', Decimal('0.99')),
#  ('BANGER PINOCCHIO', Decimal('4'), 'Bamenda', Decimal('2.99')),
#  ('BANGER PINOCCHIO', Decimal('4'), 'Jakarta', Decimal('0.99')),
#  ('BANGER PINOCCHIO', Decimal('4'), 'Jinchang', Decimal('4.99')),
#  ('BANGER PINOCCHIO', Decimal('4'), 'Katihar', Decimal('3.99')),
#  ('BANGER PINOCCHIO', Decimal('4'), 'Tychy', Decimal('2.99')),
#  ('BANGER PINOCCHIO', Decimal('4'), 'Vancouver', Decimal('0.99')),
#  ('BANGER PINOCCHIO', Decimal('4'), 'Vicente Lpez', Decimal('0.99')),
#  ('BARBARELLA STREETCAR', Decimal('1'), 'Alvorada', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', Decimal('1'), 'Bucuresti', Decimal('5.99')),
#  ('BARBARELLA STREETCAR', Decimal('1'), 'Kamakura', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', Decimal('2'), 'Ashdod', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', Decimal('2'), 'Cuernavaca', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', Decimal('2'), 'Ezeiza', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', Decimal('2'), 'Graz', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', Decimal('2'), 'Uruapan', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', Decimal('3'), 'Abha', Decimal('4.99')),
#  ('BARBARELLA STREETCAR', Decimal('3'), 'Bellevue', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', Decimal('3'), 'Gandhinagar', Decimal('3.99')),
#  ('BARBARELLA STREETCAR', Decimal('3'), 'Huixquilucan', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', Decimal('3'), 'Ikerre', Decimal('3.99')),
#  ('BARBARELLA STREETCAR', Decimal('3'), 'Maring', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', Decimal('3'), 'Richmond Hill', Decimal('4.99')),
#  ('BARBARELLA STREETCAR', Decimal('3'), 'Sal', Decimal('5.99')),
#  ('BARBARELLA STREETCAR', Decimal('3'), 'Yuncheng', Decimal('5.99')),
#  ('BARBARELLA STREETCAR', Decimal('4'), 'Hubli-Dharwad', Decimal('3.99')),
#  ('BARBARELLA STREETCAR', Decimal('4'), 'Meixian', Decimal('5.99')),
#  ('BARBARELLA STREETCAR', Decimal('4'), 'Miraj', Decimal('3.99')),
#  ('BARBARELLA STREETCAR', Decimal('4'), 'Moscow', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', Decimal('4'), 'Niznekamsk', Decimal('3.99')),
#  ('BARBARELLA STREETCAR', Decimal('4'), 'Qomsheh', Decimal('3.99')),
#  ('BARBARELLA STREETCAR', Decimal('4'), 'South Hill', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', Decimal('4'), 'Tabriz', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', Decimal('1'), 'Juazeiro do Norte', Decimal('6.99')),
#  ('BAREFOOT MANCHURIAN', Decimal('2'), 'Halifax', Decimal('4.99')),
#  ('BAREFOOT MANCHURIAN', Decimal('2'), 'Jelets', Decimal('3.99')),
#  ('BAREFOOT MANCHURIAN', Decimal('2'), 'Madiun', Decimal('3.99')),
#  ('BAREFOOT MANCHURIAN', Decimal('3'), 'Basel', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', Decimal('3'), 'Fukuyama', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', Decimal('3'), 'Halisahar', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', Decimal('3'), 'Kuwana', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', Decimal('3'), 'Pontianak', Decimal('5.99')),
#  ('BAREFOOT MANCHURIAN', Decimal('3'), 'Torren', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', Decimal('4'), 'Adoni', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', Decimal('4'), 'al-Manama', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', Decimal('4'), 'Guadalajara', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', Decimal('4'), 'Haiphong', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', Decimal('4'), 'Jastrzebie-Zdrj', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', Decimal('4'), 'Kitwe', Decimal('4.99')),
#  ('BAREFOOT MANCHURIAN', Decimal('4'), 'Le Mans', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', Decimal('4'), 'Ljubertsy', Decimal('2.99')),
#  ('BASIC EASY', Decimal('1'), 'Tianjin', Decimal('2.99')),
#  ('BASIC EASY', Decimal('2'), 'Shimoga', Decimal('2.99')),
#  ('BASIC EASY', Decimal('2'), 'Sincelejo', Decimal('2.99')),
#  ('BASIC EASY', Decimal('3'), 'Akishima', Decimal('3.99')),
#  ('BASIC EASY', Decimal('3'), 'Bayugan', Decimal('5.99')),
#  ('BASIC EASY', Decimal('3'), 'Escobar', Decimal('7.99')),
#  ('BASIC EASY', Decimal('3'), 'Jurez', Decimal('3.99')),
#  ('BASIC EASY', Decimal('3'), 'Konotop', Decimal('2.99')),
#  ('BASIC EASY', Decimal('3'), 'Santiago de Compostela', Decimal('2.99')),
#  ('BASIC EASY', Decimal('3'), 'Vancouver', Decimal('5.99')),
#  ('BASIC EASY', Decimal('3'), 'Ziguinchor', Decimal('2.99')),
#  ('BASIC EASY', Decimal('4'), 'Batman', Decimal('3.99')),
#  ('BASIC EASY', Decimal('4'), 'Haining', Decimal('2.99')),
#  ('BASIC EASY', Decimal('4'), 'Imus', Decimal('2.99')),
#  ('BASIC EASY', Decimal('4'), 'Lubumbashi', Decimal('6.99')),
#  ('BASIC EASY', Decimal('4'), 'Novi Sad', Decimal('2.99')),
#  ('BASIC EASY', Decimal('4'), 'Pjatigorsk', Decimal('2.99')),
#  ('BASIC EASY', Decimal('4'), 'Robamba', Decimal('3.99')),
#  ('BASIC EASY', Decimal('4'), 'Santa Rosa', Decimal('7.99')),
#  ('BASIC EASY', Decimal('4'), 'Simferopol', Decimal('6.99')),
#  ('BASIC EASY', Decimal('5'), 'Laohekou', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', Decimal('1'), 'Almirante Brown', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', Decimal('1'), 'Katihar', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', Decimal('2'), 'Cuautla', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', Decimal('2'), 'Kilis', Decimal('4.99')),
#  ('BEACH HEARTBREAKERS', Decimal('2'), 'Novoterkassk', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', Decimal('3'), 'Bijapur', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', Decimal('3'), 'Caracas', Decimal('4.99')),
#  ('BEACH HEARTBREAKERS', Decimal('3'), 'Crdoba', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', Decimal('3'), 'Hsichuh', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', Decimal('3'), 'Quilmes', Decimal('3.99')),
#  ('BEACH HEARTBREAKERS', Decimal('3'), 'Sterling Heights', Decimal('5.99')),
#  ('BEACH HEARTBREAKERS', Decimal('4'), 'Kingstown', Decimal('5.99')),
#  ('BEACH HEARTBREAKERS', Decimal('4'), 'Lungtan', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', Decimal('4'), 'Mysore', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', Decimal('4'), 'Pathankot', Decimal('5.99')),
#  ('BEACH HEARTBREAKERS', Decimal('4'), 'Ruse', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', Decimal('4'), 'Xiangtan', Decimal('2.99')),
#  ('BEAR GRACELAND', Decimal('1'), 'Pingxiang', Decimal('3.99')),
#  ('BEAR GRACELAND', Decimal('1'), 'Tabuk', Decimal('6.99')),
#  ('BEAR GRACELAND', Decimal('1'), 'Uijongbu', Decimal('2.99')),
#  ('BEAR GRACELAND', Decimal('2'), 'Bchar', Decimal('2.99')),
#  ('BEAR GRACELAND', Decimal('2'), 'Bhopal', Decimal('2.99')),
#  ('BEAR GRACELAND', Decimal('2'), 'Nakhon Sawan', Decimal('5.99')),
#  ('BEAR GRACELAND', Decimal('2'), 'South Hill', Decimal('2.99')),
#  ('BEAR GRACELAND', Decimal('3'), 'Angra dos Reis', Decimal('7.99')),
#  ('BEAR GRACELAND', Decimal('3'), 'Juazeiro do Norte', Decimal('7.99')),
#  ('BEAR GRACELAND', Decimal('3'), 'Olomouc', Decimal('3.99')),
#  ('BEAR GRACELAND', Decimal('3'), 'Pune', Decimal('5.99')),
#  ('BEAR GRACELAND', Decimal('3'), 'Rio Claro', Decimal('4.99')),
#  ('BEAR GRACELAND', Decimal('3'), 'Robamba', Decimal('6.99')),
#  ('BEAR GRACELAND', Decimal('3'), 'Tiefa', Decimal('3.99')),
#  ('BEAR GRACELAND', Decimal('4'), 'Addis Abeba', Decimal('2.99')),
#  ('BEAR GRACELAND', Decimal('4'), 'Ahmadnagar', Decimal('6.99')),
#  ('BEAR GRACELAND', Decimal('4'), 'Bhilwara', Decimal('2.99')),
#  ('BEAR GRACELAND', Decimal('4'), 'Czestochowa', Decimal('4.99')),
#  ('BEAR GRACELAND', Decimal('4'), 'Lapu-Lapu', Decimal('4.99')),
#  ('BEAR GRACELAND', Decimal('4'), 'Liaocheng', Decimal('7.99')),
#  ('BEAR GRACELAND', Decimal('4'), 'Mardan', Decimal('2.99')),
#  ('BEAR GRACELAND', Decimal('4'), 'Shenzhen', Decimal('2.99')),
#  ('BEAST HUNCHBACK', Decimal('1'), 'Jinzhou', Decimal('6.99')),
#  ('BEAST HUNCHBACK', Decimal('2'), 'Faaa', Decimal('4.99')),
#  ('BEAST HUNCHBACK', Decimal('2'), 'Nanyang', Decimal('4.99')),
#  ('BEAST HUNCHBACK', Decimal('3'), 'Duisburg', Decimal('4.99')),
#  ('BEAST HUNCHBACK', Decimal('3'), 'Omiya', Decimal('10.99')),
#  ('BEAST HUNCHBACK', Decimal('3'), 'Sincelejo', Decimal('8.99')),
#  ('BEAST HUNCHBACK', Decimal('4'), 'Chandrapur', Decimal('4.99')),
#  ('BEAST HUNCHBACK', Decimal('4'), 'Chiayi', Decimal('4.99')),
#  ('BEAST HUNCHBACK', Decimal('4'), 'Guadalajara', Decimal('10.99')),
#  ('BEAST HUNCHBACK', Decimal('4'), 'Kolpino', Decimal('7.99')),
#  ('BEAST HUNCHBACK', Decimal('4'), 'Zaoyang', Decimal('5.99')),
#  ('BEAUTY GREASE', Decimal('1'), 'Denizli', Decimal('6.99')),
#  ('BEAUTY GREASE', Decimal('2'), 'Barcelona', Decimal('4.99')),
#  ('BEAUTY GREASE', Decimal('2'), 'Daugavpils', Decimal('8.99')),
#  ('BEAUTY GREASE', Decimal('2'), 'Huixquilucan', Decimal('4.99')),
#  ('BEAUTY GREASE', Decimal('3'), 'Davao', Decimal('4.99')),
#  ('BEAUTY GREASE', Decimal('3'), 'Firozabad', Decimal('4.99')),
#  ('BEAUTY GREASE', Decimal('3'), 'Jaffna', Decimal('4.99')),
#  ('BEAUTY GREASE', Decimal('3'), 'Kursk', Decimal('8.99')),
#  ('BEAUTY GREASE', Decimal('3'), 'Lancaster', Decimal('8.99')),
#  ('BEAUTY GREASE', Decimal('3'), 'Mwene-Ditu', Decimal('5.99')),
#  ('BEAUTY GREASE', Decimal('3'), 'Richmond Hill', Decimal('4.99')),
#  ('BEAUTY GREASE', Decimal('3'), 'Ziguinchor', Decimal('4.99')),
#  ('BEAUTY GREASE', Decimal('4'), 'Acua', Decimal('4.99')),
#  ('BEAUTY GREASE', Decimal('4'), 'Arlington', Decimal('4.99')),
#  ('BEAUTY GREASE', Decimal('4'), 'Bhopal', Decimal('4.99')),
#  ('BEAUTY GREASE', Decimal('4'), 'Dhule (Dhulia)', Decimal('7.99')),
#  ('BEAUTY GREASE', Decimal('4'), 'Hsichuh', Decimal('4.99')),
#  ('BEAUTY GREASE', Decimal('4'), 'Kamarhati', Decimal('6.99')),
#  ('BEAUTY GREASE', Decimal('4'), 'Nezahualcyotl', Decimal('6.99')),
#  ('BEAUTY GREASE', Decimal('4'), 'Omdurman', Decimal('4.99')),
#  ('BEAUTY GREASE', Decimal('4'), 'Syktyvkar', Decimal('5.99')),
#  ('BEAUTY GREASE', Decimal('4'), 'Zhezqazghan', Decimal('4.99')),
#  ('BED HIGHBALL', Decimal('3'), 'Bhimavaram', Decimal('3.99')),
#  ('BED HIGHBALL', Decimal('3'), 'Liaocheng', Decimal('2.99')),
#  ('BED HIGHBALL', Decimal('3'), 'San Miguel de Tucumn', Decimal('2.99')),
#  ('BED HIGHBALL', Decimal('4'), 'Iligan', Decimal('2.99')),
#  ('BED HIGHBALL', Decimal('4'), 'Kursk', Decimal('5.99')),
#  ('BED HIGHBALL', Decimal('4'), 'Santo Andr', Decimal('5.99')),
#  ('BEDAZZLED MARRIED', Decimal('1'), 'Angra dos Reis', Decimal('1.99')),
#  ('BEDAZZLED MARRIED', Decimal('2'), 'Balurghat', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', Decimal('2'), 'Myingyan', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', Decimal('3'), 'Baybay', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', Decimal('3'), 'Duisburg', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', Decimal('3'), 'Le Mans', Decimal('1.99')),
#  ('BEDAZZLED MARRIED', Decimal('3'), 'Naju', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', Decimal('3'), 'San Felipe de Puerto Plata', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', Decimal('4'), 'al-Manama', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', Decimal('4'), 'Binzhou', Decimal('1.99')),
#  ('BEDAZZLED MARRIED', Decimal('4'), 'Naju', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', Decimal('4'), 'Serpuhov', Decimal('0.99')),
#  ...]

# %% [markdown]
# # Conclusion

# %% [markdown]
# - We were able to show that a start schema is easier to understand
# - Evidence that is more performant

# %%
# !PGPASSWORD=student pg_dump -h 127.0.0.1 -U student pagila > Data/pagila-star.sql

# Again, run in command line instead and provide password in 2nd step
pg_dump -h 127.0.0.1 -U student pagila > Data/pagila-star.sql
# Out:
# Der Befehl "PGPASSWORD" ist entweder falsch geschrieben oder
# konnte nicht gefunden werden.
